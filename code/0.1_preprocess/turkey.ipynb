# %%
import pandas as pd
### use xarray for extracting temperature data from .nc files
import xarray as xr 
import numpy as np
import geopandas as gpd
import datetime
import os
import metpy.calc as mpcalc
from metpy.units import units
import rioxarray
import zipfile
import os
# Directory to extract files
extract_dir = '/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/dewpoint/turkey/extracted'
gdf = gpd.read_file('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/adm0_shp/turkey/clean_shp.shp')

# %%
# Ensure the directory exists
os.makedirs(extract_dir, exist_ok=True)


# Unzip the NetCDF files
for year in ['2018', '2019', '2020', '2021', '2022']:
    zip_path = f'/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/dewpoint/turkey/unextracted/era5_land_dewpoint_us_{year}.netcdf.zip'
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
                # Rename extracted files
        for file_name in zip_ref.namelist():
            if file_name.endswith('.nc'):
                old_file_path = os.path.join(extract_dir, file_name)
                new_file_path = os.path.join(extract_dir, f'era5_land_dewpoint_us_{year}.nc')
                os.rename(old_file_path, new_file_path)

# Unzip leftover_months NetCDF files
for year in ['2018', '2019', '2020', '2021', '2022']:
    zip_path = f'/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/dewpoint/turkey/unextracted/era5_land_dewpoint_us_{year}_xtra.netcdf.zip'
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
                # Rename extracted files
        for file_name in zip_ref.namelist():
            if file_name.endswith('.nc'):
                old_file_path = os.path.join(extract_dir, file_name)
                new_file_path = os.path.join(extract_dir, f'era5_land_dewpoint_us_{year}_xtra.nc')
                os.rename(old_file_path, new_file_path)

# %%
data_arrays = []
for year in ['2018', '2019', '2020', '2021', '2022']:

    nc_file = os.path.join(extract_dir, f'era5_land_dewpoint_us_{year}.nc')
    ds_main = xr.open_dataset(nc_file)

    nc_file_xtra = os.path.join(extract_dir, f'era5_land_dewpoint_us_{year}_xtra.nc')
    ds_xtra = xr.open_dataset(nc_file_xtra)


    ds = xr.concat([ds_main, ds_xtra], dim='valid_time')
    ds = ds.sortby('valid_time')

    # Rename 'valid_time' to 'time'
    ds = ds.rename({'valid_time': 'time'})
    
    # Convert time to the desired timezone (e.g., 'America/Denver')
    ds['time'] = ds['time'] + pd.Timedelta(hours=3)

    # Convert from Kelvin to Celsius
    ds['t2m'] = ds['t2m'] - 273.15
    ds['d2m'] = ds['d2m'] - 273.15

    # Calculate relative humidity
    ds['rh'] = mpcalc.relative_humidity_from_dewpoint(ds['t2m'] * units.degC, ds['d2m'] * units.degC)
    ds['rh'] = ds['rh'] * 100

    # Calculate THI using metpy's heat_index function
    ds['thi'] = mpcalc.heat_index(ds['t2m'] * units.degC, ds['rh'] * units.percent, mask_undefined=False)


    daily_max_thi = ds.resample(time='1D').max()

    data_arrays.append(daily_max_thi)

    print('appended')

concat_daily_max = xr.concat(data_arrays, dim='time')
# Out:
# appended
# appended
# appended
# appended
# appended

# %%
concat_daily_max.to_netcdf('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/THI/turkey/array/concat_array.nc')

# %%
concat_daily_max = xr.open_dataset('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/THI/turkey/array/concat_array.nc')
concat_daily_max.rio.write_crs(4326, inplace=True)
# Out:
# <xarray.Dataset> Size: 185MB
# Dimensions:      (latitude: 63, longitude: 189, time: 775)
# Coordinates:
#     number       int64 8B ...
#   * latitude     (latitude) float64 504B 42.01 41.91 41.81 ... 36.01 35.91 35.81
#   * longitude    (longitude) float64 2kB 25.91 26.01 26.11 ... 44.51 44.61 44.71
#   * time         (time) datetime64[ns] 6kB 2018-05-01 2018-05-02 ... 2022-10-02
#     spatial_ref  int64 8B 0
# Data variables:
#     t2m          (time, latitude, longitude) float32 37MB ...
#     d2m          (time, latitude, longitude) float32 37MB ...
#     rh           (time, latitude, longitude) float32 37MB ...
#     thi          (time, latitude, longitude) float64 74MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-09-19T09:16 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
concat_daily_max['longitude'].mean()
# Out:
# <xarray.DataArray 'longitude' ()> Size: 8B
# array(35.309)
# Coordinates:
#     number       int64 8B ...
#     spatial_ref  int64 8B 0

# %%
data_dic = {}

for idx, row in gdf.iterrows():

    adm2 = row['adm2_tr']
    adm1 = row['adm1_tr']
    # Clip the THI DataArray using the geometry
    try:
        clipped_thi = concat_daily_max.rio.clip([row.geometry], all_touched=True, crs=gdf.crs)
        
        # Convert the clipped THI DataArray to a DataFrame
        clipped_thi_df = clipped_thi.to_dataframe().reset_index()
        
        # Add the adm2 information to the DataFrame

        clipped_thi_df = clipped_thi_df.groupby('time').mean(numeric_only=True).reset_index()

        clipped_thi_df['adm2'] = adm2
        
        clipped_thi_df['adm1'] = adm1

        data_dic[f'{adm1}_{adm2}'] = clipped_thi_df

        print(f'{adm1}_{adm2} appended')

    except:
        continue
# Out:
# İSTANBUL_ŞİŞLİ appended
# İZMİR_ÇİĞLİ appended
# İSTANBUL_ŞİLE appended
# GÜMÜŞHANE_ŞİRAN appended
# SİİRT_ŞİRVAN appended
# ÇANKIRI_ŞABANÖZÜ appended
# GAZİANTEP_ŞAHİNBEY appended
# TRABZON_ŞALPAZARI appended
# KÜTAHYA_ŞAPHANE appended
# ISPARTA_ŞARKİKARAAĞAÇ appended
# TEKİRDAĞ_ŞARKÖY appended
# ARTVİN_ŞAVŞAT appended
# ANTALYA_İBRADI appended
# ŞIRNAK_İDİL appended
# GİRESUN_ŞEBİNKARAHİSAR appended
# YOZGAT_ŞEFAATLİ appended
# GAZİANTEP_ŞEHİTKAMİL appended
# MANİSA_ŞEHZADELER appended
# KIRŞEHİR_ÇİÇEKDAĞI appended
# HAKKARİ_ŞEMDİNLİ appended
# ERZURUM_ŞENKAYA appended
# KASTAMONU_ŞENPAZAR appended
# ANKARA_ŞEREFLİKOÇHİSAR appended
# ESKİŞEHIR_ÇİFTELER appended
# NİĞDE_ÇİFTLİK appended
# YALOVA_ÇİFTLİKKÖY appended
# AFYONKARAHİSAR_İHSANİYE appended
# KASTAMONU_İHSANGAZİ appended
# ŞIRNAK_ŞIRNAK appended
# ORDU_İKİZCE appended
# RİZE_İKİZDERE appended
# ERZİNCAN_İLİÇ appended
# DÜZCE_ÇİLİMLİ appended
# SAMSUN_İLKADIM appended
# ADANA_İMAMOĞLU appended
# SİVAS_İMRANLI appended
# AYDIN_İNCİRLİOVA appended
# KAYSERİ_İNCESU appended
# AYDIN_ÇİNE appended
# KASTAMONU_İNEBOLU appended
# BURSA_İNEGÖL appended
# BİLECİK_İNHİSAR appended
# ESKİŞEHIR_İNÖNÜ appended
# VAN_İPEKYOLU appended
# EDİRNE_İPSALA appended
# AFYONKARAHİSAR_İSCEHİSAR appended
# ÇORUM_İSKİLİP appended
# HATAY_İSKENDERUN appended
# GAZİANTEP_İSLAHİYE appended
# ERZURUM_İSPİR appended
# AFYONKARAHİSAR_ŞUHUT appended
# DENİZLİ_ÇİVRİL appended
# BALIKESİR_İVRİNDİ appended
# RİZE_İYİDERE appended
# KOCAELİ_İZMİT appended
# BURSA_İZNİK appended
# SAMSUN_19 MAYIS appended
# AKSARAY_AĞAÇÖREN appended
# ELAZIĞ_AĞIN appended
# ERZURUM_AŞKALE appended
# BURDUR_AĞLASUN appended
# KAHRAMANMARAŞ_ÇAĞLAYANCERİT appended
# KASTAMONU_AĞLI appended
# AĞRI_AĞRI appended
# KASTAMONU_ABANA appended
# NEVŞEHİR_ACIGÖL appended
# DENİZLİ_ACIPAYAM appended
# BİTLİS_ADİLCEVAZ appended
# BİNGÖL_ADAKLI appended
# İSTANBUL_ADALAR appended
# SAKARYA_ADAPAZARI appended
# ADIYAMAN_ADIYAMAN appended
# KAHRAMANMARAŞ_AFŞİN appended
# AFYONKARAHİSAR_AFYONKARAHISAR appended
# KONYA_AHIRLI appended
# BİTLİS_AHLAT appended
# MANİSA_AHMETLİ appended
# KONYA_AKŞEHİR appended
# TRABZON_AKÇAABAT appended
# MALATYA_AKÇADAĞ appended
# ŞANLIURFA_AKÇAKALE appended
# KIRŞEHİR_AKÇAKENT appended
# DÜZCE_AKÇAKOCA appended
# YOZGAT_AKDAĞMADENİ appended
# MERSİN_AKDENİZ appended
# MANİSA_AKHİSAR appended
# SİVAS_AKINCILAR appended
# KAYSERİ_AKKIŞLA appended
# ORDU_AKKUŞ appended
# KIRŞEHİR_AKPINAR appended
# KONYA_AKÖREN appended
# ANTALYA_AKSEKİ appended
# ANTALYA_AKSU appended
# ISPARTA_AKSU appended
# KARS_AKYAKA appended
# SAKARYA_AKYAZI appended
# ANKARA_AKYURT appended
# DENİZLİ_ÇAL appended
# İZMİR_ALİAĞA appended
# MANİSA_ALAŞEHİR appended
# SAMSUN_ALAÇAM appended
# ÇORUM_ALACA appended
# ELAZIĞ_ALACAKAYA appended
# ADANA_ALADAĞ appended
# ANTALYA_ALANYA appended
# ZONGULDAK_ALAPLI appended
# VAN_ÇALDIRAN appended
# TOKAT_ALMUS appended
# ESKİŞEHIR_ALPU appended
# BALIKESİR_ALTIEYLÜL appended
# ANKARA_ALTINDAĞ appended
# KONYA_ALTINEKİN appended
# ORDU_ALTINORDU appended
# YALOVA_ALTINOVA appended
# KÜTAHYA_ALTINTAŞ appended
# BURDUR_ALTINYAYLA appended
# SİVAS_ALTINYAYLA appended
# HATAY_ALTINÖZÜ appended
# NİĞDE_ALTUNHİSAR appended
# GİRESUN_ALUCRA appended
# ORDU_ÇAMAŞ appended
# NİĞDE_ÇAMARDI appended
# BARTIN_AMASRA appended
# AMASYA_AMASYA appended
# DENİZLİ_ÇAMELİ appended
# ANKARA_ÇAMLIDERE appended
# RİZE_ÇAMLIHEMŞİN appended
# MERSİN_ÇAMLIYAYLA appended
# GİRESUN_ÇAMOLUK appended
# ÇANAKKALE_ÇAN appended
# GİRESUN_ÇANAKÇI appended
# ÇANAKKALE_ÇANAKKALE appended
# MERSİN_ANAMUR appended
# YOZGAT_ÇANDIR appended
# KAHRAMANMARAŞ_ANDIRIN appended
# ANKARA_ÇANKAYA appended
# ÇANKIRI_ÇANKIRI appended
# HATAY_ANTAKYA appended
# SAMSUN_ÇARŞAMBA appended
# SAKARYA_ARİFİYE appended
# TRABZON_ÇARŞIBAŞI appended
# KASTAMONU_ARAÇ appended
# GAZİANTEP_ARABAN appended
# TRABZON_ARAKLI appended
# IĞDIR_ARALIK appended
# MALATYA_ARAPGİR appended
# ARDAHAN_ARDAHAN appended
# DENİZLİ_ÇARDAK appended
# ARTVİN_ARDANUÇ appended
# RİZE_ARDEŞEN appended
# MALATYA_ARGUVAN appended
# ARTVİN_ARHAVİ appended
# ELAZIĞ_ARICAK appended
# YALOVA_ARMUTLU appended
# İSTANBUL_ARNAVUTKÖY appended
# KARS_ARPAÇAY appended
# TRABZON_ARSİN appended
# HATAY_ARSUZ appended
# TOKAT_ARTOVA appended
# MARDİN_ARTUKLU appended
# ARTVİN_ARTVIN appended
# SAMSUN_ASARCIK appended
# KÜTAHYA_ASLANAPA appended
# ERZURUM_ÇAT appended
# İSTANBUL_ATAŞEHİR appended
# ISPARTA_ATABEY appended
# VAN_ÇATAK appended
# SAMSUN_ATAKUM appended
# İSTANBUL_ÇATALCA appended
# ORDU_ÇATALPINAR appended
# KASTAMONU_ÇATALZEYTİN appended
# ÇANKIRI_ATKARACALAR appended
# NEVŞEHİR_AVANOS appended
# İSTANBUL_AVCILAR appended
# KÜTAHYA_ÇAVDARHİSAR appended
# BURDUR_ÇAVDIR appended
# AFYONKARAHİSAR_ÇAY appended
# ANKARA_AYAŞ appended
# SİNOP_AYANCIK appended
# ORDU_ÇAYBAŞI appended
# ORDU_AYBASTI appended
# ZONGULDAK_ÇAYCUMA appended
# MERSİN_AYDINCIK appended
# YOZGAT_AYDINCIK appended
# BAYBURT_AYDINTEPE appended
# RİZE_ÇAYELİ appended
# YOZGAT_ÇAYIRALAN appended
# ERZİNCAN_ÇAYIRLI appended
# KOCAELİ_ÇAYIROVA appended
# TRABZON_ÇAYKARA appended
# KARAMAN_AYRANCI appended
# ÇANAKKALE_AYVACIK appended
# SAMSUN_AYVACIK appended
# BALIKESİR_AYVALIK appended
# ERZURUM_AZİZİYE appended
# KASTAMONU_AZDAVAY appended
# ÇANAKKALE_BİGA appended
# BALIKESİR_BİGADİÇ appended
# ŞANLIURFA_BİRECİK appended
# DİYARBAKIR_BİSMİL appended
# TOKAT_BAŞÇİFTLİK appended
# KOCAELİ_BAŞİSKELE appended
# İSTANBUL_BAŞAKŞEHİR appended
# İSTANBUL_BAĞCILAR appended
# VAN_BAŞKALE appended
# DİYARBAKIR_BAĞLAR appended
# AFYONKARAHİSAR_BAŞMAKÇI appended
# KARAMAN_BAŞYAYLA appended
# DENİZLİ_BABADAĞ appended
# KIRKLARELİ_BABAESKİ appended
# SAMSUN_BAFRA appended
# KIRIKKALE_BAHŞİLİ appended
# OSMANİYE_BAHÇE appended
# İSTANBUL_BAHÇELİEVLER appended
# VAN_BAHÇESARAY appended
# İSTANBUL_BAKIRKÖY appended
# DENİZLİ_BAKLAN appended
# ANKARA_BALA appended
# KIRIKKALE_BALIŞEYH appended
# İZMİR_BALÇOVA appended
# BALIKESİR_BALYA appended
# UŞAK_BANAZ appended
# BALIKESİR_BANDIRMA appended
# BARTIN_BARTIN appended
# ELAZIĞ_BASKİL appended
# BATMAN_BATMAN appended
# MALATYA_BATTALGAZİ appended
# AFYONKARAHİSAR_BAYAT appended
# ÇORUM_BAYAT appended
# BAYBURT_BAYBURT appended
# İZMİR_BAYINDIR appended
# SİİRT_BAYKAN appended
# İZMİR_BAYRAKLI appended
# ÇANAKKALE_BAYRAMİÇ appended
# İSTANBUL_BAYRAMPAŞA appended
# ÇANKIRI_BAYRAMÖREN appended
# TRABZON_BEŞİKDÜZÜ appended
# İSTANBUL_BEŞİKTAŞ appended
# BATMAN_BEŞİRİ appended
# DENİZLİ_BEKİLLİ appended
# HATAY_BELEN appended
# İZMİR_BERGAMA appended
# ADIYAMAN_BESNİ appended
# KONYA_BEYŞEHİR appended
# DENİZLİ_BEYAĞAÇ appended
# İZMİR_BEYDAĞ appended
# İSTANBUL_BEYKOZ appended
# İSTANBUL_BEYLİKDÜZÜ appended
# ESKİŞEHIR_BEYLİKOVA appended
# İSTANBUL_BEYOĞLU appended
# ANKARA_BEYPAZARI appended
# ŞIRNAK_BEYTÜŞŞEBAP appended
# BİLECİK_BILECIK appended
# BİNGÖL_BINGÖL appended
# BİTLİS_BITLIS appended
# KAYSERİ_BÜNYAN appended
# ÇORUM_BOĞAZKALE appended
# YOZGAT_BOĞAZLIYAN appended
# MUĞLA_BODRUM appended
# BOLU_BOLU appended
# AFYONKARAHİSAR_BOLVADİN appended
# NİĞDE_BOR appended
# ARTVİN_BORÇKA appended
# İZMİR_BORNOVA appended
# SİNOP_BOYABAT appended
# ÇANAKKALE_BOZCAADA appended
# AYDIN_BOZDOĞAN appended
# KONYA_BOZKIR appended
# DENİZLİ_BOZKURT appended
# KASTAMONU_BOZKURT appended
# ŞANLIURFA_BOZOVA appended
# KIRŞEHİR_BOZTEPE appended
# MERSİN_BOZYAZI appended
# BİLECİK_BOZÜYÜK appended
# İZMİR_BUCA appended
# BURDUR_BUCAK appended
# AYDIN_BUHARKENT appended
# GİRESUN_BULANCAK appended
# MUŞ_BULANIK appended
# DENİZLİ_BULDAN appended
# BURDUR_BURDUR appended
# BALIKESİR_BURHANİYE appended
# İSTANBUL_BÜYÜKÇEKMECE appended
# BURSA_BÜYÜKORHAN appended
# KASTAMONU_CİDE appended
# KONYA_CİHANBEYLİ appended
# ŞIRNAK_CİZRE appended
# SAMSUN_CANİK appended
# ADANA_CEYHAN appended
# ŞANLIURFA_CEYLANPINAR appended
# DÜZCE_CUMAYERİ appended
# DİYARBAKIR_DİCLE appended
# AYDIN_DİDİM appended
# ANTALYA_DÖŞEMEALTI appended
# KARS_DİGOR appended
# İZMİR_DİKİLİ appended
# SİNOP_DİKMEN appended
# KOCAELİ_DİLOVASI appended
# AFYONKARAHİSAR_DİNAR appended
# SİVAS_DİVRİĞİ appended
# AĞRI_DİYADİN appended
# KASTAMONU_DADAY appended
# MUĞLA_DALAMAN appended
# ARDAHAN_DAMAL appended
# MALATYA_DARENDE appended
# MARDİN_DARGEÇİT appended
# KOCAELİ_DARICA appended
# MUĞLA_DATÇA appended
# AFYONKARAHİSAR_DAZKIRI appended
# HATAY_DEFNE appended
# KIRIKKALE_DELİCE appended
# İZMİR_ÖDEMİŞ appended
# MANİSA_DEMİRCİ appended
# KIRKLARELİ_DEMİRKÖY appended
# BAYBURT_DEMİRÖZÜ appended
# ANTALYA_DEMRE appended
# MARDİN_DERİK appended
# KOCAELİ_DERİNCE appended
# NEVŞEHİR_DERİNKUYU appended
# KONYA_DERBENT appended
# KONYA_DEREBUCAK appended
# GİRESUN_DERELİ appended
# RİZE_DEREPAZARI appended
# TRABZON_DERNEKPAZARI appended
# KAYSERİ_DEVELİ appended
# ZONGULDAK_DEVREK appended
# KASTAMONU_DEVREKÂNİ appended
# SİVAS_DOĞANŞAR appended
# MALATYA_DOĞANŞEHİR appended
# KONYA_DOĞANHİSAR appended
# GİRESUN_DOĞANKENT appended
# MALATYA_DOĞANYOL appended
# KASTAMONU_DOĞANYURT appended
# AĞRI_DOĞUBAYAZIT appended
# ÇORUM_DODURGA appended
# KÜTAHYA_DOMANİÇ appended
# BOLU_DÖRTDİVAN appended
# HATAY_DÖRTYOL appended
# KAHRAMANMARAŞ_DULKADİROĞLU appended
# KÜTAHYA_DUMLUPINAR appended
# SİNOP_DURAĞAN appended
# BALIKESİR_DURSUNBEY appended
# OSMANİYE_DÜZİÇİ appended
# DÜZCE_DÜZCE appended
# TRABZON_DÜZKÖY appended
# DİYARBAKIR_EĞİL appended
# ISPARTA_EĞİRDİR appended
# İZMİR_ÇEŞME appended
# UŞAK_EŞME appended
# ÇANAKKALE_ECEABAT appended
# EDİRNE_EDIRNE appended
# BALIKESİR_EDREMİT appended
# VAN_EDREMİT appended
# AYDIN_EFELER appended
# KARABÜK_EFLANİ appended
# KAHRAMANMARAŞ_EKİNÖZÜ appended
# YOZGAT_ÇEKEREK appended
# İSTANBUL_ÇEKMEKÖY appended
# ADIYAMAN_ÇELİKHAN appended
# ELAZIĞ_ELAZIĞ appended
# KAHRAMANMARAŞ_ELBİSTAN appended
# KİLİS_ELBEYLİ appended
# ÇANKIRI_ELDİVAN appended
# AĞRI_ELEŞKİRT appended
# KIRIKKALE_ÇELEBİ appended
# ANKARA_ELMADAĞ appended
# ANTALYA_ELMALI appended
# KONYA_ÇELTİK appended
# BURDUR_ÇELTİKÇİ appended
# TUNCELİ_ÇEMİŞGEZEK appended
# AFYONKARAHİSAR_EMİRDAĞ appended
# KONYA_EMİRGAZİ appended
# KÜTAHYA_EMET appended
# EDİRNE_ENEZ appended
# TOKAT_ERBAA appended
# VAN_ERCİŞ appended
# BALIKESİR_ERDEK appended
# MERSİN_ERDEMLİ appended
# KONYA_EREĞLİ appended
# ZONGULDAK_EREĞLİ appended
# SAKARYA_ERENLER appended
# SİNOP_ERFELEK appended
# DİYARBAKIR_ERGANİ appended
# TEKİRDAĞ_ERGENE appended
# ÇANKIRI_ÇERKEŞ appended
# TEKİRDAĞ_ÇERKEZKÖY appended
# DİYARBAKIR_ÇERMİK appended
# KARAMAN_ERMENEK appended
# SİİRT_ERUH appended
# HATAY_ERZİN appended
# ERZİNCAN_ERZINCAN appended
# İSTANBUL_ESENLER appended
# İSTANBUL_ESENYURT appended
# KARABÜK_ESKİPAZAR appended
# GİRESUN_ESPİYE appended
# ANKARA_ETİMESGUT appended
# AFYONKARAHİSAR_EVCİLER appended
# ANKARA_EVREN appended
# GİRESUN_EYNESİL appended
# İSTANBUL_EYÜPSULTAN appended
# ŞANLIURFA_EYYÜBİYE appended
# ÇANAKKALE_EZİNE appended
# ANTALYA_FİNİKE appended
# İSTANBUL_FATİH appended
# ORDU_FATSA appended
# ADANA_FEKE appended
# KAYSERİ_FELAHİYE appended
# SAKARYA_FERİZLİ appended
# MUĞLA_FETHİYE appended
# RİZE_FINDIKLI appended
# İZMİR_FOÇA appended
# İSTANBUL_GAZİ OSMANPAŞA appended
# İZMİR_GAZİEMİR appended
# ANTALYA_GAZİPAŞA appended
# GİRESUN_GÜCE appended
# ANKARA_GÜDÜL appended
# KOCAELİ_GEBZE appended
# KÜTAHYA_GEDİZ appended
# ÇANAKKALE_GELİBOLU appended
# ISPARTA_GELENDOST appended
# SİVAS_GEMEREK appended
# BURSA_GEMLİK appended
# BİNGÖL_GENÇ appended
# BATMAN_GERCÜŞ appended
# BOLU_GEREDE appended
# ADIYAMAN_GERGER appended
# AYDIN_GERMENCİK appended
# SİNOP_GERZE appended
# VAN_GEVAŞ appended
# SAKARYA_GEYVE appended
# GİRESUN_GIRESUN appended
# ÇANAKKALE_GÖKÇEADA appended
# ZONGULDAK_GÖKÇEBEY appended
# KAHRAMANMARAŞ_GÖKSUN appended
# NEVŞEHİR_GÜLŞEHİR appended
# AKSARAY_GÜLAĞAÇ appended
# ADIYAMAN_GÖLBAŞI appended
# ANKARA_GÖLBAŞI appended
# KOCAELİ_GÖLCÜK appended
# ARDAHAN_GÖLE appended
# BURDUR_GÖLHİSAR appended
# ŞIRNAK_GÜÇLÜKONAK appended
# ORDU_GÖLKÖY appended
# MANİSA_GÖLMARMARA appended
# MERSİN_GÜLNAR appended
# SİVAS_GÖLOVA appended
# BİLECİK_GÖLPAZARI appended
# DÜZCE_GÖLYAKA appended
# ORDU_GÜLYALI appended
# AMASYA_GÜMÜŞHACIKÖY appended
# GÜMÜŞHANE_GÜMÜŞHANE appended
# DÜZCE_GÜMÜŞOVA appended
# BALIKESİR_GÖMEÇ appended
# ANTALYA_GÜNDOĞMUŞ appended
# BALIKESİR_GÖNEN appended
# ISPARTA_GÖNEN appended
# DENİZLİ_GÜNEY appended
# KONYA_GÜNEYSINIR appended
# RİZE_GÜNEYSU appended
# İSTANBUL_GÜNGÖREN appended
# ESKİŞEHIR_GÜNYÜZÜ appended
# MANİSA_GÖRDES appended
# GİRESUN_GÖRELE appended
# ORDU_GÜRGENTEPE appended
# SİVAS_GÜRÜN appended
# BİTLİS_GÜROYMAK appended
# VAN_GÜRPINAR appended
# BURSA_GÜRSU appended
# AMASYA_GÖYNÜCEK appended
# BOLU_GÖYNÜK appended
# İZMİR_GÜZELBAHÇE appended
# AKSARAY_GÜZELYURT appended
# ŞANLIURFA_HİLVAN appended
# KÜTAHYA_HİSARCIK appended
# BİTLİS_HİZAN appended
# NEVŞEHİR_HACIBEKTAŞ appended
# KAYSERİ_HACILAR appended
# KONYA_HADİM appended
# SİVAS_HAFİK appended
# HAKKARİ_HAKKARI appended
# ŞANLIURFA_HALİLİYE appended
# ŞANLIURFA_HALFETİ appended
# KONYA_HALKAPINAR appended
# AMASYA_HAMAMÖZÜ appended
# AĞRI_HAMUR appended
# ESKİŞEHIR_HAN appended
# DİYARBAKIR_HANİ appended
# ARDAHAN_HANAK appended
# KASTAMONU_HANÖNÜ appended
# BURSA_HARMANCIK appended
# ŞANLIURFA_HARRAN appended
# OSMANİYE_HASANBEYLİ appended
# BATMAN_HASANKEYF appended
# MUŞ_HASKÖY appended
# HATAY_HASSA appended
# BALIKESİR_HAVRAN appended
# EDİRNE_HAVSA appended
# SAMSUN_HAVZA appended
# ANKARA_HAYMANA appended
# TEKİRDAĞ_HAYRABOLU appended
# TRABZON_HAYRAT appended
# DİYARBAKIR_HAZRO appended
# MALATYA_HEKİMHAN appended
# RİZE_HEMŞİN appended
# SAKARYA_HENDEK appended
# ERZURUM_HINIS appended
# AFYONKARAHİSAR_HOCALAR appended
# DENİZLİ_HONAZ appended
# ARTVİN_HOPA appended
# ERZURUM_HORASAN appended
# TUNCELİ_HOZAT appended
# KONYA_HÜYÜK appended
# IĞDIR_IĞDIR appended
# ARDAHAN_ÇILDIR appended
# ÇANKIRI_ILGAZ appended
# KONYA_ILGIN appended
# DİYARBAKIR_ÇINAR appended
# YALOVA_ÇINARCIK appended
# ISPARTA_ISPARTA appended
# BİNGÖL_KİĞI appended
# AYDIN_KÖŞK appended
# ZONGULDAK_KİLİMLİ appended
# İZMİR_KİRAZ appended
# ANTALYA_KAŞ appended
# İSTANBUL_KAĞITHANE appended
# KARS_KAĞIZMAN appended
# ORDU_KABADÜZ appended
# ORDU_KABATAŞ appended
# OSMANİYE_KADİRLİ appended
# YOZGAT_KADIŞEHRİ appended
# İSTANBUL_KADIKÖY appended
# KONYA_KADINHANI appended
# ANKARA_KAHRAMANKAZAN appended
# DENİZLİ_KALE appended
# MALATYA_KALE appended
# ANKARA_KALECİK appended
# RİZE_KALKANDERE appended
# KIRŞEHİR_KAMAN appended
# KOCAELİ_KANDIRA appended
# SİVAS_KANGAL appended
# TEKİRDAĞ_KAPAKLI appended
# İZMİR_KARŞIYAKA appended
# ADANA_KARAİSALI appended
# İZMİR_KARABAĞLAR appended
# KARABÜK_KARABÜK appended
# İZMİR_KARABURUN appended
# BURSA_KARACABEY appended
# AYDIN_KARACASU appended
# UŞAK_KARAHALLI appended
# KIRIKKALE_KARAKEÇİLİ appended
# ELAZIĞ_KARAKOÇAN appended
# IĞDIR_KARAKOYUNLU appended
# ŞANLIURFA_KARAKÖPRÜ appended
# KARAMAN_KARAMAN appended
# BURDUR_KARAMANLI appended
# KOCAELİ_KARAMÜRSEL appended
# ERZURUM_KARAÇOBAN appended
# KONYA_KARAPINAR appended
# SAKARYA_KARAPÜRÇEK appended
# SAKARYA_KARASU appended
# ADANA_KARATAŞ appended
# KONYA_KARATAY appended
# ERZURUM_KARAYAZI appended
# BALIKESİR_KARESİ appended
# ÇORUM_KARGI appended
# GAZİANTEP_KARKAMIŞ appended
# BİNGÖL_KARLIOVA appended
# AYDIN_KARPUZLU appended
# KARS_KARS appended
# İSTANBUL_KARTAL appended
# KOCAELİ_KARTEPE appended
# KASTAMONU_KASTAMONU appended
# SAMSUN_KAVAK appended
# MUĞLA_KAVAKLIDERE appended
# DİYARBAKIR_KAYAPINAR appended
# DÜZCE_KAYNAŞLI appended
# SAKARYA_KAYNARCA appended
# KARAMAN_KAZIMKARABEKİR appended
# EDİRNE_KEŞAN appended
# GİRESUN_KEŞAP appended
# ISPARTA_KEÇİBORLU appended
# ANKARA_KEÇİÖREN appended
# ELAZIĞ_KEBAN appended
# BURSA_KELES appended
# GÜMÜŞHANE_KELKİT appended
# ERZİNCAN_KEMAH appended
# ERZİNCAN_KEMALİYE appended
# İZMİR_KEMALPAŞA appended
# ANTALYA_KEMER appended
# BURDUR_KEMER appended
# ANTALYA_KEPEZ appended
# BALIKESİR_KEPSUT appended
# KIRIKKALE_KESKİN appended
# BURSA_KESTEL appended
# ADIYAMAN_KÂHTA appended
# BOLU_KIBRISCIK appended
# KİLİS_KILIS appended
# İZMİR_KINIK appended
# KIRŞEHİR_KIRŞEHIR appended
# HATAY_KIRIKHAN appended
# KIRIKKALE_KIRIKKALE appended
# MANİSA_KIRKAĞAÇ appended
# KIRKLARELİ_KIRKLARELI appended
# ANKARA_KIZILCAHAMAM appended
# ÇANKIRI_KIZILIRMAK appended
# AFYONKARAHİSAR_KIZILÖREN appended
# MARDİN_KIZILTEPE appended
# İSTANBUL_KÜÇÜKÇEKMECE appended
# AYDIN_KOÇARLI appended
# SAKARYA_KOCAALİ appended
# DİYARBAKIR_KOCAKÖY appended
# KAYSERİ_KOCASİNAN appended
# KIRKLARELİ_KOFÇAZ appended
# İZMİR_KONAK appended
# ANTALYA_KONYAALTI appended
# ORDU_KORGAN appended
# ÇANKIRI_KORGUN appended
# MUŞ_KORKUT appended
# ANTALYA_KORKUTELİ appended
# ELAZIĞ_KOVANCILAR appended
# SİVAS_KOYULHİSAR appended
# NEVŞEHİR_KOZAKLI appended
# ADANA_KOZAN appended
# ZONGULDAK_KOZLU appended
# BATMAN_KOZLUK appended
# MANİSA_KÖPRÜBAŞI appended
# TRABZON_KÖPRÜBAŞI appended
# ERZURUM_KÖPRÜKÖY appended
# KASTAMONU_KÜRE appended
# KOCAELİ_KÖRFEZ appended
# GÜMÜŞHANE_KÜRTÜN appended
# GÜMÜŞHANE_KÖSE appended
# KÜTAHYA_KÜTAHYA appended
# AYDIN_KUŞADASI appended
# MANİSA_KULA appended
# DİYARBAKIR_KULP appended
# KONYA_KULU appended
# MALATYA_KULUNCAK appended
# HATAY_KUMLU appended
# ANTALYA_KUMLUCA appended
# ORDU_KUMRU appended
# ÇANKIRI_KURŞUNLU appended
# SİİRT_KURTALAN appended
# BARTIN_KURUCAŞİLE appended
# AYDIN_KUYUCAK appended
# MUĞLA_KÖYCEĞİZ appended
# DİYARBAKIR_LİCE appended
# ÇORUM_LÂÇİN appended
# SAMSUN_LADİK appended
# EDİRNE_LALAPAŞA appended
# KIRKLARELİ_LÜLEBURGAZ appended
# ÇANAKKALE_LÂPSEKİ appended
# MARDİN_MİDYAT appended
# ESKİŞEHIR_MİHALGAZİ appended
# ESKİŞEHIR_MİHALIÇÇIK appended
# MUĞLA_MİLAS appended
# ELAZIĞ_MADEN appended
# ESKİŞEHIR_MAHMUDİYE appended
# TRABZON_MAÇKA appended
# MUŞ_MALAZGİRT appended
# TEKİRDAĞ_MALKARA appended
# İSTANBUL_MALTEPE appended
# ANKARA_MAMAK appended
# ANTALYA_MANAVGAT appended
# BALIKESİR_MANYAS appended
# MUĞLA_MARMARİS appended
# BALIKESİR_MARMARA appended
# TEKİRDAĞ_MARMARA EREĞLİSİ appended
# TUNCELİ_MAZGİRT appended
# MARDİN_MAZIDAĞI appended
# ÇORUM_MECİTÖZÜ appended
# KAYSERİ_MELİKGAZİ appended
# İZMİR_MENDERES appended
# İZMİR_MENEMEN appended
# BOLU_MENGEN appended
# MUĞLA_MENTEŞE appended
# EDİRNE_MERİÇ appended
# KONYA_MERAM appended
# DENİZLİ_MERKEZEFENDİ appended
# MARDİN_ÖMERLİ appended
# AMASYA_MERZİFON appended
# ORDU_MESUDİYE appended
# MERSİN_MEZİTLİ appended
# İSTANBUL_ÜMRANİYE appended
# MUŞ_MUŞ appended
# KIRŞEHİR_MUCUR appended
# BURSA_MUDANYA appended
# BOLU_MUDURNU appended
# VAN_MURADİYE appended
# TEKİRDAĞ_MURATLI appended
# ANTALYA_MURATPAŞA appended
# ARTVİN_MURGUL appended
# KİLİS_MUSABEYLİ appended
# BURSA_MUSTAFAKEMALPAŞA appended
# MERSİN_MUT appended
# BİTLİS_MUTKİ appended
# TOKAT_NİKSAR appended
# BURSA_NİLÜFER appended
# GAZİANTEP_NİZİP appended
# ANKARA_NALLIHAN appended
# İZMİR_NARLIDERE appended
# ERZURUM_NARMAN appended
# AYDIN_NAZİLLİ appended
# TUNCELİ_NAZIMİYE appended
# NEVŞEHİR_NEVŞEHIR appended
# DİYARBAKIR_ÇÜNGÜŞ appended
# NİĞDE_NIĞDE appended
# GAZİANTEP_NURDAĞI appended
# KAHRAMANMARAŞ_NURHAK appended
# MARDİN_NUSAYBİN appended
# ORDU_ÜNYE appended
# GAZİANTEP_OĞUZELİ appended
# ÇORUM_OĞUZLAR appended
# AFYONKARAHİSAR_ÇOBANLAR appended
# ESKİŞEHIR_ODUNPAZARI appended
# TRABZON_OF appended
# ERZURUM_OLTU appended
# ERZURUM_OLUR appended
# KAHRAMANMARAŞ_ONİKİ ŞUBAT appended
# BURSA_ORHANELİ appended
# BURSA_ORHANGAZİ appended
# TEKİRDAĞ_ÇORLU appended
# ÇANKIRI_ORTA appended
# MUĞLA_ORTACA appended
# TRABZON_ORTAHİSAR appended
# AKSARAY_ORTAKÖY appended
# ÇORUM_ORTAKÖY appended
# ÇORUM_ÇORUM appended
# ÇORUM_OSMANCIK appended
# BİLECİK_OSMANELİ appended
# BURSA_OSMANGAZİ appended
# OSMANİYE_OSMANIYE appended
# ERZİNCAN_OTLUKBELİ appended
# KARABÜK_OVACIK appended
# TUNCELİ_OVACIK appended
# GİRESUN_PİRAZİZ appended
# ERZURUM_PALANDÖKEN appended
# ELAZIĞ_PALU appended
# DENİZLİ_PAMUKKALE appended
# SAKARYA_PAMUKOVA appended
# ERZURUM_PASİNLER appended
# AĞRI_PATNOS appended
# HATAY_PAYAS appended
# RİZE_PAZAR appended
# TOKAT_PAZAR appended
# KAHRAMANMARAŞ_PAZARCIK appended
# KÜTAHYA_PAZARLAR appended
# BİLECİK_PAZARYERİ appended
# ERZURUM_PAZARYOLU appended
# KIRKLARELİ_PEHLİVANKÖY appended
# İSTANBUL_PENDİK appended
# ORDU_PERŞEMBE appended
# TUNCELİ_PERTEK appended
# SİİRT_PERVARİ appended
# KASTAMONU_PINARBAŞI appended
# KAYSERİ_PINARBAŞI appended
# KIRKLARELİ_PINARHİSAR appended
# TUNCELİ_PÜLÜMÜR appended
# KİLİS_POLATELİ appended
# ANKARA_POLATLI appended
# ARDAHAN_POSOF appended
# ADANA_POZANTI appended
# MALATYA_PÜTÜRGE appended
# ANKARA_PURSAKLAR appended
# TOKAT_REŞADİYE appended
# ERZİNCAN_REFAHİYE appended
# HATAY_REYHANLI appended
# NEVŞEHİR_ÜRGÜP appended
# RİZE_RIZE appended
# MERSİN_SİLİFKE appended
# İSTANBUL_SİLİVRİ appended
# ŞIRNAK_SİLOPİ appended
# DİYARBAKIR_SİLVAN appended
# KÜTAHYA_SİMAV appended
# AFYONKARAHİSAR_SİNANPAŞA appended
# ADIYAMAN_SİNCİK appended
# ANKARA_SİNCAN appended
# BİLECİK_SÖĞÜT appended
# SAKARYA_SÖĞÜTLÜ appended
# UŞAK_SİVASLI appended
# ŞANLIURFA_SİVEREK appended
# ELAZIĞ_SİVRİCE appended
# ESKİŞEHIR_SİVRİHİSAR appended
# ADANA_SAİMBEYLİ appended
# KARABÜK_SAFRANBOLU appended
# MANİSA_SALİHLİ appended
# SAMSUN_SALIPAZARI appended
# HATAY_SAMANDAĞ appended
# ADIYAMAN_SAMSAT appended
# İSTANBUL_SANCAKTEPE appended
# AFYONKARAHİSAR_SANDIKLI appended
# SAKARYA_SAPANCA appended
# TEKİRDAĞ_SARAY appended
# VAN_SARAY appended
# SİNOP_SARAYDÜZÜ appended
# YOZGAT_SARAYKENT appended
# DENİZLİ_SARAYKÖY appended
# KONYA_SARAYÖNÜ appended
# ADANA_SARIÇAM appended
# ESKİŞEHIR_SARICAKAYA appended
# MANİSA_SARIGÖL appended
# KARS_SARIKAMIŞ appended
# YOZGAT_SARIKAYA appended
# KAYSERİ_SARIOĞLAN appended
# KARAMAN_SARIVELİLER appended
# AKSARAY_SARIYAHŞİ appended
# İSTANBUL_SARIYER appended
# KAYSERİ_SARIZ appended
# SİVAS_SARKIŞLA appended
# MANİSA_SARUHANLI appended
# BATMAN_SASON appended
# BALIKESİR_SAVAŞTEPE appended
# MARDİN_SAVUR appended
# BOLU_SEBEN appended
# İZMİR_SEFERİHİSAR appended
# KARS_SELİM appended
# MANİSA_SELENDİ appended
# İZMİR_SELÇUK appended
# KONYA_SELÇUKLU appended
# ISPARTA_SENİRKENT appended
# ANTALYA_SERİK appended
# DENİZLİ_SERİNHİSAR appended
# SAKARYA_SERDİVAN appended
# ESKİŞEHIR_SEYİTGAZİ appended
# KONYA_SEYDİŞEHİR appended
# MUĞLA_SEYDİKEMER appended
# KASTAMONU_SEYDİLER appended
# ADANA_SEYHAN appended
# SİİRT_SIIRT appended
# BALIKESİR_SINDIRGI appended
# SİNOP_SINOP appended
# SİVAS_SIVAS appended
# İSTANBUL_ÜSKÜDAR appended
# AYDIN_SÖKE appended
# TEKİRDAĞ_SÜLEYMANPAŞA appended
# EDİRNE_SÜLOĞLU appended
# BİNGÖL_SOLHAN appended
# MANİSA_SOMA appended
# YOZGAT_SORGUN appended
# TRABZON_SÜRMENE appended
# ISPARTA_SÜTÇÜLER appended
# SİVAS_SUŞEHRİ appended
# KIRIKKALE_SULAKYURT appended
# İSTANBUL_SULTANBEYLİ appended
# AFYONKARAHİSAR_SULTANDAĞI appended
# İSTANBUL_SULTANGAZİ appended
# AYDIN_SULTANHİSAR appended
# AMASYA_SULUOVA appended
# TOKAT_SULUSARAY appended
# OSMANİYE_SUMBAS appended
# ÇORUM_SUNGURLU appended
# DİYARBAKIR_SUR appended
# ŞANLIURFA_SURUÇ appended
# BALIKESİR_SUSURLUK appended
# KARS_SUSUZ appended
# SİİRT_TİLLO appended
# İZMİR_TİRE appended
# GİRESUN_TİREBOLU appended
# KONYA_TAŞKENT appended
# KASTAMONU_TAŞKÖPRÜ appended
# AĞRI_TAŞLIÇAY appended
# AMASYA_TAŞOVA appended
# KAYSERİ_TALAS appended
# SAKARYA_TARAKLI appended
# MERSİN_TARSUS appended
# BİTLİS_TATVAN appended
# KÜTAHYA_TAVŞANLI appended
# DENİZLİ_TAVAS appended
# BURDUR_TEFENNİ appended
# SAMSUN_TEKKEKÖY appended
# ERZURUM_TEKMAN appended
# ESKİŞEHIR_TEPEBAŞI appended
# ERZİNCAN_TERCAN appended
# YALOVA_TERMAL appended
# SAMSUN_TERME appended
# TOKAT_TOKAT appended
# KAYSERİ_TOMARZA appended
# TRABZON_TONYA appended
# OSMANİYE_TOPRAKKALE appended
# İZMİR_TORBALI appended
# MERSİN_TOROSLAR appended
# ERZURUM_TORTUM appended
# GÜMÜŞHANE_TORUL appended
# KASTAMONU_TOSYA appended
# SİNOP_TÜRKELİ appended
# KAHRAMANMARAŞ_TÜRKOĞLU appended
# VAN_TUŞBA appended
# ADANA_TUFANBEYLİ appended
# TUNCELİ_TUNCELI appended
# MANİSA_TURGUTLU appended
# TOKAT_TURHAL appended
# ADIYAMAN_TUT appended
# AĞRI_TUTAK appended
# İSTANBUL_TUZLA appended
# IĞDIR_TUZLUCA appended
# KONYA_TUZLUKÇU appended
# UŞAK_UŞAK appended
# ÇORUM_UĞURLUDAĞ appended
# ANKARA_ÇUBUK appended
# HAKKARİ_ÇUKURCA appended
# ADANA_ÇUKUROVA appended
# MUĞLA_ULA appended
# SİVAS_ULAŞ appended
# ORDU_ULUBEY appended
# UŞAK_ULUBEY appended
# ISPARTA_ULUBORLU appended
# ŞIRNAK_ULUDERE appended
# NİĞDE_ULUKIŞLA appended
# BARTIN_ULUS appended
# KONYA_ÇUMRA appended
# İZMİR_URLA appended
# ERZURUM_UZUNDERE appended
# EDİRNE_UZUNKÖPRÜ appended
# ŞANLIURFA_VİRANŞEHİR appended
# KIRKLARELİ_VİZE appended
# TRABZON_VAKFIKEBİR appended
# MUŞ_VARTO appended
# SAMSUN_VEZİRKÖPRÜ appended
# GİRESUN_YAĞLIDERE appended
# KIRIKKALE_YAHŞİHAN appended
# KAYSERİ_YAHYALI appended
# SAMSUN_YAKAKENT appended
# ERZURUM_YAKUTİYE appended
# KONYA_YALIHÜYÜK appended
# YALOVA_YALOVA appended
# ISPARTA_YALVAÇ appended
# ÇANKIRI_YAPRAKLI appended
# MUĞLA_YATAĞAN appended
# GAZİANTEP_YAVUZELİ appended
# HATAY_YAYLADAĞI appended
# BİNGÖL_YAYLADERE appended
# MALATYA_YAZIHAN appended
# KAYSERİ_YEŞİLHİSAR appended
# MARDİN_YEŞİLLİ appended
# BURDUR_YEŞİLOVA appended
# MALATYA_YEŞİLYURT appended
# TOKAT_YEŞİLYURT appended
# BİNGÖL_YEDİSU appended
# ISPARTA_YENİŞARBADEMLİ appended
# BURSA_YENİŞEHİR appended
# DİYARBAKIR_YENİŞEHİR appended
# MERSİN_YENİŞEHİR appended
# BOLU_YENİÇAĞA appended
# ÇANAKKALE_YENİCE appended
# KARABÜK_YENİCE appended
# YOZGAT_YENİFAKILI appended
# ANKARA_YENİMAHALLE appended
# AYDIN_YENİPAZAR appended
# BİLECİK_YENİPAZAR appended
# YOZGAT_YERKÖY appended
# DÜZCE_YIĞILCA appended
# BURSA_YILDIRIM appended
# SİVAS_YILDIZELİ appended
# HAKKARİ_YÜKSEKOVA appended
# TRABZON_YOMRA appended
# YOZGAT_YOZGAT appended
# ADANA_YÜREĞİR appended
# ADANA_YUMURTALIK appended
# KONYA_YUNAK appended
# MANİSA_YUNUSEMRE appended
# ARTVİN_YUSUFELİ appended
# TOKAT_ZİLE appended
# VAN_ÖZALP appended
# SİVAS_ZARA appended
# İSTANBUL_ZEYTİNBURNU appended
# ERZİNCAN_ÜZÜMLÜ appended
# ZONGULDAK_ZONGULDAK appended
# KAYSERİ_ÖZVATAN appended
# AKSARAY_SULTANHANI appended
# ARTVİN_KEMALPAŞA appended
# HAKKARİ_DERECİK appended
# AKSARAY_AKSARAY appended
# AKSARAY_ESKİL appended

# %%
final_concat = pd.concat(data_dic.values(), ignore_index=True)

# %%
final_concat.drop(columns=['latitude', 'longitude'], inplace=True)

# %%
final_concat.to_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/THI/turkey/daily_max_THI.csv')

# %%
df = pd.read_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/THI/turkey/daily_max_THI.csv')
