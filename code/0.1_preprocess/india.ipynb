# %%
import pandas as pd
### use xarray for extracting temperature data from .nc files
import xarray as xr 
import numpy as np
import geopandas as gpd
import datetime
import os
import metpy.calc as mpcalc
from metpy.units import units
import rioxarray
import zipfile
import os

# Directory to extract files
extract_dir = '/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/dewpoint/india/extracted'
gdf = gpd.read_file('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/adm0_shp/india/final_clean_shp.shp')

# %%
# Ensure the directory exists
os.makedirs(extract_dir, exist_ok=True)


# Unzip the NetCDF files
for year in ['2018', '2019', '2020', '2021', '2022']:
    zip_path = f'/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/dewpoint/india/unextracted/era5_land_dewpoint_{year}.netcdf.zip'
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
                # Rename extracted files
        for file_name in zip_ref.namelist():
            if file_name.endswith('.nc'):
                old_file_path = os.path.join(extract_dir, file_name)
                new_file_path = os.path.join(extract_dir, f'era5_land_dewpoint_{year}.nc')
                os.rename(old_file_path, new_file_path)

# %%
data_arrays = []
for year in ['2018', '2019', '2020', '2021', '2022']:

    nc_file = os.path.join(extract_dir, f'era5_land_dewpoint_{year}.nc')
    ds = xr.open_dataset(nc_file)

    ds = ds.sortby('valid_time')

    # Rename 'valid_time' to 'time'
    ds = ds.rename({'valid_time': 'time'})
    
    # Convert time to the desired timezone (e.g., 'Indian Standard Time')
    ds['time'] = ds['time'] + pd.Timedelta(hours=5, minutes=30)

    # Convert from Kelvin to Celsius
    ds['t2m'] = ds['t2m'] - 273.15
    ds['d2m'] = ds['d2m'] - 273.15

    # Calculate relative humidity
    ds['rh'] = mpcalc.relative_humidity_from_dewpoint(ds['t2m'] * units.degC, ds['d2m'] * units.degC)
    ds['rh'] = ds['rh'] * 100

    # Calculate THI using metpy's heat_index function
    ds['thi'] = mpcalc.heat_index(ds['t2m'] * units.degC, ds['rh'] * units.percent, mask_undefined=False)


    daily_max_thi = ds.resample(time='1D').max()

    data_arrays.append(daily_max_thi)

    print('appended')

    
concat_daily_max = xr.concat(data_arrays, dim='time')
# Out:
# appended
# appended
# appended
# appended
# appended

# %%
concat_daily_max.to_netcdf('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/THI/india/concat_array.nc')

# %%
concat_daily_max = xr.open_dataset('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/THI/india/array/concat_array.nc')
concat_daily_max.rio.write_crs(4326, inplace=True)
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:      (latitude: 310, longitude: 286, time: 925)
# Coordinates:
#     number       int64 8B ...
#   * latitude     (latitude) float64 2kB 37.6 37.5 37.4 37.3 ... 7.0 6.9 6.8 6.7
#   * longitude    (longitude) float64 2kB 68.7 68.8 68.9 69.0 ... 97.0 97.1 97.2
#   * time         (time) datetime64[ns] 7kB 2018-03-01 2018-03-02 ... 2022-09-01
#     spatial_ref  int64 8B 0
# Data variables:
#     t2m          (time, latitude, longitude) float32 328MB ...
#     d2m          (time, latitude, longitude) float32 328MB ...
#     rh           (time, latitude, longitude) float32 328MB ...
#     thi          (time, latitude, longitude) float64 656MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-09-16T12:30 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
data_dic = {}

for idx, row in gdf.iterrows():

    adm2 = row['adm2']
    adm1 = row['adm1']
    # Clip the THI DataArray using the geometry
    try:
        clipped_thi = concat_daily_max.rio.clip([row.geometry], all_touched=True, crs=gdf.crs)
        
        # Convert the clipped THI DataArray to a DataFrame
        clipped_thi_df = clipped_thi.to_dataframe().reset_index()
        
        # Add the adm2 information to the DataFrame

        clipped_thi_df = clipped_thi_df.groupby('time').mean(numeric_only=True).reset_index()

        clipped_thi_df['adm2'] = adm2
        
        clipped_thi_df['adm1'] = adm1

        data_dic[f'{adm1}_{adm2}'] = clipped_thi_df

        print(f'{adm1}_{adm2} appended')

    except:
        continue
# Out:
# Jammu and Kashmir_Kupwara appended
# Jammu and Kashmir_Bandipore appended
# Jammu and Kashmir_Baramula appended
# Jammu and Kashmir_Ganderbal appended
# Jammu and Kashmir_Anantnag appended
# Jammu and Kashmir_Kishtwar appended
# Jammu and Kashmir_Srinagar appended
# Jammu and Kashmir_Badgam appended
# Jammu and Kashmir_Pulwama appended
# Jammu and Kashmir_Punch appended
# Jammu and Kashmir_Shupiyan appended
# Jammu and Kashmir_Kulgam appended
# Jammu and Kashmir_Rajouri appended
# Jammu and Kashmir_Ramban appended
# Jammu and Kashmir_Reasi appended
# Jammu and Kashmir_Doda appended
# Jammu and Kashmir_Jammu appended
# Jammu and Kashmir_Kathua appended
# Jammu and Kashmir_Udhampur appended
# Jammu and Kashmir_Samba appended
# Jammu and Kashmir_Muzaffarabad appended
# Jammu and Kashmir_Mirpur appended
# Himachal Pradesh_Lahul & Spiti appended
# Himachal Pradesh_Chamba appended
# Himachal Pradesh_Kangra appended
# Himachal Pradesh_Kullu appended
# Himachal Pradesh_Mandi appended
# Himachal Pradesh_Kinnaur appended
# Himachal Pradesh_Una appended
# Himachal Pradesh_Shimla appended
# Himachal Pradesh_Solan appended
# Himachal Pradesh_Sirmaur appended
# Himachal Pradesh_Hamirpur appended
# Himachal Pradesh_Bilaspur appended
# Punjab_Gurdaspur appended
# Punjab_Hoshiarpur appended
# Punjab_Amritsar appended
# Punjab_Jalandhar appended
# Punjab_Tarn Taran appended
# Punjab_Rupnagar appended
# Punjab_Shaheed Bhagat Singh Nagar appended
# Punjab_Fazilka appended
# Punjab_Moga appended
# Punjab_Ludhiana appended
# Punjab_Sahibzada Ajit Singh Nagar appended
# Punjab_Faridkot appended
# Punjab_Fatehgarh Sahib appended
# Punjab_Sri Muktsar Sahib appended
# Punjab_Sangrur appended
# Punjab_Barnala appended
# Punjab_Bathinda appended
# Punjab_Patiala appended
# Punjab_Mansa appended
# Punjab_Ferozepur appended
# Punjab_Pathankot appended
# Punjab_Kapurthala appended
# Chandigarh_Chandigarh appended
# Uttarakhand_Uttarkashi appended
# Uttarakhand_Chamoli appended
# Uttarakhand_Dehradun appended
# Uttarakhand_Tehri Garhwal appended
# Uttarakhand_Rudraprayag appended
# Uttarakhand_Pithoragarh appended
# Uttarakhand_Bageshwar appended
# Uttarakhand_Haridwar appended
# Uttarakhand_Pauri Garhwal appended
# Uttarakhand_Almora appended
# Uttarakhand_Nainital appended
# Uttarakhand_Champawat appended
# Uttarakhand_Udham Singh Nagar appended
# Haryana_Jhajjar appended
# Haryana_Gurgaon appended
# Haryana_Faridabad appended
# Haryana_Mahendragarh appended
# Haryana_Rewari appended
# Haryana_Mewat appended
# Haryana_Palwal appended
# Haryana_Charki Dadri appended
# Haryana_Yamuna Nagar appended
# Haryana_Kurukshetra appended
# Haryana_Kaithal appended
# Haryana_Sirsa appended
# Haryana_Karnal appended
# Haryana_Jind appended
# Haryana_Fatehabad appended
# Haryana_Hisar appended
# Haryana_Panipat appended
# Haryana_Sonepat appended
# Haryana_Bhiwani appended
# Haryana_Rohtak appended
# Haryana_Panchkula appended
# Haryana_Ambala appended
# Delhi_North Delhi appended
# Delhi_North East Delhi appended
# Delhi_West Delhi appended
# Delhi_East Delhi appended
# Delhi_South West Delhi appended
# Delhi_Central Delhi appended
# Delhi_New Delhi appended
# Delhi_South Delhi appended
# Delhi_Shahdara appended
# Delhi_South East Delhi appended
# Delhi_North West Delhi appended
# Rajasthan_Churu appended
# Rajasthan_Jhunjhunu appended
# Rajasthan_Jaisalmer appended
# Rajasthan_Sikar appended
# Rajasthan_Alwar appended
# Rajasthan_Jaipur appended
# Rajasthan_Jodhpur appended
# Rajasthan_Bharatpur appended
# Rajasthan_Nagaur appended
# Rajasthan_Dausa appended
# Rajasthan_Karauli appended
# Rajasthan_Dhaulpur appended
# Rajasthan_Barmer appended
# Rajasthan_Sawai Madhopur appended
# Rajasthan_Tonk appended
# Rajasthan_Pali appended
# Rajasthan_Bhilwara appended
# Rajasthan_Jalore appended
# Rajasthan_Bundi appended
# Rajasthan_Kota appended
# Rajasthan_Sirohi appended
# Rajasthan_Baran appended
# Rajasthan_Udaipur appended
# Rajasthan_Jhalawar appended
# Rajasthan_Dungarpur appended
# Rajasthan_Banswara appended
# Rajasthan_Ajmer appended
# Rajasthan_Rajsamand appended
# Rajasthan_Chittaurgarh appended
# Rajasthan_Sri Ganganagar appended
# Rajasthan_Hanumangarh appended
# Rajasthan_Bikaner appended
# Rajasthan_Pratapgarh appended
# Uttar Pradesh_Amroha appended
# Uttar Pradesh_Hapur appended
# Uttar Pradesh_Bareilly appended
# Uttar Pradesh_Pilibhit appended
# Uttar Pradesh_Bulandshahar appended
# Uttar Pradesh_Gautam Buddh Nagar appended
# Uttar Pradesh_Lakhimpur Kheri appended
# Uttar Pradesh_Badaun appended
# Uttar Pradesh_Bahraich appended
# Uttar Pradesh_Shahjahanpur appended
# Uttar Pradesh_Aligarh appended
# Uttar Pradesh_Kanshi Ram Nagar appended
# Uttar Pradesh_Mathura appended
# Uttar Pradesh_Shrawasti appended
# Uttar Pradesh_Sitapur appended
# Uttar Pradesh_Hathras appended
# Uttar Pradesh_Etah appended
# Uttar Pradesh_Hardoi appended
# Uttar Pradesh_Farrukhabad appended
# Uttar Pradesh_Firozabad appended
# Uttar Pradesh_Siddharthnagar appended
# Uttar Pradesh_Mainpuri appended
# Uttar Pradesh_Maharajganj appended
# Uttar Pradesh_Agra appended
# Uttar Pradesh_Gonda appended
# Uttar Pradesh_Barabanki appended
# Uttar Pradesh_Kushinagar appended
# Uttar Pradesh_Kannauj appended
# Uttar Pradesh_Lucknow appended
# Uttar Pradesh_Basti appended
# Uttar Pradesh_Gorakhpur appended
# Uttar Pradesh_Sant Kabir Nagar appended
# Uttar Pradesh_Unnao appended
# Uttar Pradesh_Etawah appended
# Uttar Pradesh_Kanpur Nagar appended
# Uttar Pradesh_Auraiya appended
# Uttar Pradesh_Ayodhya appended
# Uttar Pradesh_Kanpur Dehat appended
# Uttar Pradesh_Deoria appended
# Uttar Pradesh_Sultanpur appended
# Uttar Pradesh_Ambedkar Nagar appended
# Uttar Pradesh_Rae Bareli appended
# Uttar Pradesh_Jalaun appended
# Uttar Pradesh_Azamgarh appended
# Uttar Pradesh_Mau appended
# Uttar Pradesh_Fatehpur appended
# Uttar Pradesh_Ballia appended
# Uttar Pradesh_Jaunpur appended
# Uttar Pradesh_Jhansi appended
# Uttar Pradesh_Banda appended
# Uttar Pradesh_Ghazipur appended
# Uttar Pradesh_Kaushambi appended
# Uttar Pradesh_Prayagraj appended
# Uttar Pradesh_Varanasi appended
# Uttar Pradesh_Chitrakoot appended
# Uttar Pradesh_Chandauli appended
# Uttar Pradesh_Sant Ravidas Nagar appended
# Uttar Pradesh_Mirzapur appended
# Uttar Pradesh_Lalitpur appended
# Uttar Pradesh_Sonbhadra appended
# Uttar Pradesh_Amethi appended
# Uttar Pradesh_Ghaziabad appended
# Uttar Pradesh_Sambhal appended
# Uttar Pradesh_Mahoba appended
# Uttar Pradesh_Saharanpur appended
# Uttar Pradesh_Bijnor appended
# Uttar Pradesh_Muzaffarnagar appended
# Uttar Pradesh_Bagpat appended
# Uttar Pradesh_Meerut appended
# Uttar Pradesh_Moradabad appended
# Uttar Pradesh_Rampur appended
# Uttar Pradesh_Shamli appended
# Uttar Pradesh_Balrampur appended
# Uttar Pradesh_Hamirpur appended
# Uttar Pradesh_Pratapgarh appended
# Bihar_Pashchim Champaran appended
# Bihar_Purvi Champaran appended
# Bihar_Sitamarhi appended
# Bihar_Sheohar appended
# Bihar_Gopalganj appended
# Bihar_Samastipur appended
# Bihar_Katihar appended
# Bihar_Khagaria appended
# Bihar_Bhojpur appended
# Bihar_Buxar appended
# Bihar_Darbhanga appended
# Bihar_Saharsa appended
# Bihar_Kaimur appended
# Bihar_Rohtas appended
# Bihar_Jamui appended
# Bihar_Banka appended
# Bihar_Nawada appended
# Bihar_Gaya appended
# Bihar_Munger appended
# Bihar_Vaishali appended
# Bihar_Begusarai appended
# Bihar_Bhagalpur appended
# Bihar_Lakhisarai appended
# Bihar_Sheikhpura appended
# Bihar_Arwal appended
# Bihar_Jehanabad appended
# Bihar_Nalanda appended
# Bihar_Patna appended
# Bihar_Saran appended
# Bihar_Siwan appended
# Bihar_Muzaffarpur appended
# Bihar_Madhepura appended
# Bihar_Araria appended
# Bihar_Supaul appended
# Bihar_Madhubani appended
# Bihar_Purnia appended
# Bihar_Kishanganj appended
# Bihar_Aurangabad appended
# Sikkim_North Sikkim appended
# Sikkim_West Sikkim appended
# Sikkim_South Sikkim appended
# Sikkim_East Sikkim appended
# Arunachal Pradesh_Upper Subansiri appended
# Arunachal Pradesh_Anjaw appended
# Arunachal Pradesh_Changlang appended
# Arunachal Pradesh_Tawang appended
# Arunachal Pradesh_Papum Pare appended
# Arunachal Pradesh_Tirap appended
# Arunachal Pradesh_East Siang appended
# Arunachal Pradesh_Lohit appended
# Arunachal Pradesh_Kurung Kumey appended
# Arunachal Pradesh_Lower Subansiri appended
# Arunachal Pradesh_East Kameng appended
# Arunachal Pradesh_West Kameng appended
# Arunachal Pradesh_Kra Daadi appended
# Arunachal Pradesh_Namsai appended
# Arunachal Pradesh_Longding appended
# Arunachal Pradesh_Upper Siang appended
# Arunachal Pradesh_Lower Siang appended
# Arunachal Pradesh_Upper Dibang Valley appended
# Arunachal Pradesh_Lower Dibang Valley appended
# Arunachal Pradesh_Siang appended
# Arunachal Pradesh_Shi Yomi appended
# Arunachal Pradesh_Pakke Kessang appended
# Arunachal Pradesh_West Siang appended
# Arunachal Pradesh_Lepa Rada appended
# Arunachal Pradesh_Kamle appended
# Nagaland_Mon appended
# Nagaland_Longleng appended
# Nagaland_Mokokchung appended
# Nagaland_Tuensang appended
# Nagaland_Kiphire appended
# Nagaland_Peren appended
# Nagaland_Wokha appended
# Nagaland_Zunheboto appended
# Nagaland_Phek appended
# Nagaland_Kohima appended
# Nagaland_Dimapur appended
# Manipur_Kamjong appended
# Manipur_Senapati appended
# Manipur_Tamenglong appended
# Manipur_Imphal West appended
# Manipur_Kakching appended
# Manipur_Bishnupur appended
# Manipur_Chandel appended
# Manipur_Churachandpur appended
# Manipur_Imphal East appended
# Manipur_Jiribam appended
# Manipur_Kangpokpi appended
# Manipur_Thoubal appended
# Manipur_Tengnoupal appended
# Manipur_Ukhrul appended
# Manipur_Noney appended
# Manipur_Pherzawl appended
# Mizoram_Kolasib appended
# Mizoram_Mamit appended
# Mizoram_Serchhip appended
# Mizoram_Lunglei appended
# Mizoram_Saiha appended
# Mizoram_Lawngtlai appended
# Mizoram_Hnahthial appended
# Mizoram_Saitual appended
# Mizoram_Aizawl appended
# Mizoram_Champhai appended
# Mizoram_Khawzawl appended
# Tripura_North Tripura appended
# Tripura_Dhalai appended
# Tripura_Sipahijala appended
# Tripura_Gomati appended
# Tripura_Khowai appended
# Tripura_West Tripura appended
# Tripura_South Tripura appended
# Tripura_Unakoti appended
# Meghalaya_Ri-Bhoi appended
# Meghalaya_West Khasi Hills appended
# Meghalaya_East Jaintia Hills appended
# Meghalaya_East Khasi Hills appended
# Meghalaya_South Garo Hills appended
# Meghalaya_West Garo Hills appended
# Meghalaya_East Garo Hills appended
# Meghalaya_West Jaintia Hills appended
# Meghalaya_South West Khasi Hills appended
# Meghalaya_North Garo Hills appended
# Meghalaya_South West Garo Hills appended
# Assam_Tinsukia appended
# Assam_Dhemaji appended
# Assam_Dibrugarh appended
# Assam_Lakhimpur appended
# Assam_Sivasagar appended
# Assam_Jorhat appended
# Assam_Sonitpur appended
# Assam_Golaghat appended
# Assam_Udalguri appended
# Assam_Chirang appended
# Assam_Baksa appended
# Assam_Nagaon appended
# Assam_Kokrajhar appended
# Assam_Darrang appended
# Assam_Barpeta appended
# Assam_Nalbari appended
# Assam_Morigaon appended
# Assam_Kamrup appended
# Assam_Bongaigaon appended
# Assam_Dhubri appended
# Assam_Kamrup Metropolitan appended
# Assam_Goalpara appended
# Assam_Dima Hasao appended
# Assam_Cachar appended
# Assam_Karimganj appended
# Assam_Hailakandi appended
# Assam_Charaideo appended
# Assam_Majuli appended
# Assam_Biswanath appended
# Assam_Hojai appended
# Assam_South Salmara Mancachar appended
# Assam_Karbi Anglong appended
# Assam_West Karbi Anglong appended
# West Bengal_South 24 Parganas appended
# West Bengal_Darjeeling appended
# West Bengal_Jalpaiguri appended
# West Bengal_Dakshin Dinajpur appended
# West Bengal_Malda appended
# West Bengal_Murshidabad appended
# West Bengal_Birbhum appended
# West Bengal_Nadia appended
# West Bengal_Bardhaman appended
# West Bengal_Purulia appended
# West Bengal_Bankura appended
# West Bengal_North 24 Parganas appended
# West Bengal_Hooghly appended
# West Bengal_West Medinipur appended
# West Bengal_Howrah appended
# West Bengal_Kolkata appended
# West Bengal_Purba Medinipur appended
# West Bengal_Alipurduar appended
# West Bengal_Paschim Bardhaman appended
# West Bengal_Kalimpong appended
# West Bengal_Jhargram appended
# West Bengal_Cooch Behar appended
# West Bengal_Uttar Dinajpur appended
# Jharkhand_Sahibganj appended
# Jharkhand_Godda appended
# Jharkhand_Pakur appended
# Jharkhand_Giridih appended
# Jharkhand_Dumka appended
# Jharkhand_Deoghar appended
# Jharkhand_Palamu appended
# Jharkhand_Chatra appended
# Jharkhand_Garhwa appended
# Jharkhand_Jamtara appended
# Jharkhand_Dhanbad appended
# Jharkhand_Latehar appended
# Jharkhand_Bokaro appended
# Jharkhand_Ramgarh appended
# Jharkhand_Ranchi appended
# Jharkhand_Lohardaga appended
# Jharkhand_Gumla appended
# Jharkhand_Khunti appended
# Jharkhand_Seraikela Kharsawan appended
# Jharkhand_East Singhbhum appended
# Jharkhand_West Singhbhum appended
# Jharkhand_Simdega appended
# Jharkhand_Koderma appended
# Jharkhand_Hazaribagh appended
# Odisha_Bhadrak appended
# Odisha_Dhenkanal appended
# Odisha_Jajpur appended
# Odisha_Subarnapur appended
# Odisha_Nuapada appended
# Odisha_Balangir appended
# Odisha_Boudh appended
# Odisha_Cuttack appended
# Odisha_Kandhamal appended
# Odisha_Nayagarh appended
# Odisha_Khordha appended
# Odisha_Kalahandi appended
# Odisha_Jagatsinghpur appended
# Odisha_Puri appended
# Odisha_Nabarangpur appended
# Odisha_Rayagada appended
# Odisha_Koraput appended
# Odisha_Malkangiri appended
# Odisha_Angul appended
# Odisha_Kendrapara appended
# Odisha_Ganjam appended
# Odisha_Gajapati appended
# Odisha_Mayurbhanj appended
# Odisha_Sundargarh appended
# Odisha_Kendujhar appended
# Odisha_Balasore appended
# Odisha_Jharsuguda appended
# Odisha_Bargarh appended
# Odisha_Deogarh appended
# Odisha_Sambalpur appended
# Chhattisgarh_Mahasamund appended
# Chhattisgarh_Kanker appended
# Chhattisgarh_Narayanpur appended
# Chhattisgarh_Dantewada appended
# Chhattisgarh_Bastar appended
# Chhattisgarh_Kondagaon appended
# Chhattisgarh_Gariaband appended
# Chhattisgarh_Raipur appended
# Chhattisgarh_Durg appended
# Chhattisgarh_Dhamtari appended
# Chhattisgarh_Balod appended
# Chhattisgarh_Koriya appended
# Chhattisgarh_Jashpur appended
# Chhattisgarh_Korba appended
# Chhattisgarh_Kawardha appended
# Chhattisgarh_Janjgir-Champa appended
# Chhattisgarh_Bemetara appended
# Chhattisgarh_Rajnandgaon appended
# Chhattisgarh_Surajpur appended
# Chhattisgarh_Baloda Bazar appended
# Chhattisgarh_Mungeli appended
# Chhattisgarh_Surguja appended
# Chhattisgarh_Balrampur appended
# Chhattisgarh_Bijapur appended
# Chhattisgarh_Raigarh appended
# Chhattisgarh_Bilaspur appended
# Chhattisgarh_Sukma appended
# Madhya Pradesh_Burhanpur appended
# Madhya Pradesh_Morena appended
# Madhya Pradesh_Bhind appended
# Madhya Pradesh_Gwalior appended
# Madhya Pradesh_Sheopur appended
# Madhya Pradesh_Shivpuri appended
# Madhya Pradesh_Tikamgarh appended
# Madhya Pradesh_Neemuch appended
# Madhya Pradesh_Rewa appended
# Madhya Pradesh_Satna appended
# Madhya Pradesh_Guna appended
# Madhya Pradesh_Ashoknagar appended
# Madhya Pradesh_Mandsaur appended
# Madhya Pradesh_Singrauli appended
# Madhya Pradesh_Sidhi appended
# Madhya Pradesh_Sagar appended
# Madhya Pradesh_Damoh appended
# Madhya Pradesh_Shajapur appended
# Madhya Pradesh_Vidisha appended
# Madhya Pradesh_Rajgarh appended
# Madhya Pradesh_Shahdol appended
# Madhya Pradesh_Katni appended
# Madhya Pradesh_Umaria appended
# Madhya Pradesh_Ratlam appended
# Madhya Pradesh_Bhopal appended
# Madhya Pradesh_Ujjain appended
# Madhya Pradesh_Raisen appended
# Madhya Pradesh_Sehore appended
# Madhya Pradesh_Jabalpur appended
# Madhya Pradesh_Dewas appended
# Madhya Pradesh_Anuppur appended
# Madhya Pradesh_Jhabua appended
# Madhya Pradesh_Dindori appended
# Madhya Pradesh_Narsinghpur appended
# Madhya Pradesh_Dhar appended
# Madhya Pradesh_Indore appended
# Madhya Pradesh_Mandla appended
# Madhya Pradesh_Hoshangabad appended
# Madhya Pradesh_Seoni appended
# Madhya Pradesh_Alirajpur appended
# Madhya Pradesh_Chhindwara appended
# Madhya Pradesh_Harda appended
# Madhya Pradesh_Khargone appended
# Madhya Pradesh_Khandwa appended
# Madhya Pradesh_Balaghat appended
# Madhya Pradesh_Barwani appended
# Madhya Pradesh_Agar appended
# Madhya Pradesh_Datia appended
# Madhya Pradesh_Chhatarpur appended
# Madhya Pradesh_Panna appended
# Madhya Pradesh_Betul appended
# Madhya Pradesh_Niwari appended
# Gujarat_Valsad appended
# Gujarat_Amreli appended
# Gujarat_Dang appended
# Gujarat_Banaskantha appended
# Gujarat_Patan appended
# Gujarat_Mehsana appended
# Gujarat_Gandhinagar appended
# Gujarat_Ahmedabad appended
# Gujarat_Panchmahal appended
# Gujarat_Dahod appended
# Gujarat_Vadodara appended
# Gujarat_Bharuch appended
# Gujarat_Porbandar appended
# Gujarat_Narmada appended
# Gujarat_Surat appended
# Gujarat_Tapi appended
# Gujarat_Aravalli appended
# Gujarat_Botad appended
# Gujarat_Chhota Udaipur appended
# Gujarat_Mahisagar appended
# Gujarat_Gir Somnath appended
# Gujarat_Sabarkatha appended
# Gujarat_Kutch appended
# Gujarat_Surendranagar appended
# Gujarat_Rajkot appended
# Gujarat_Kheda appended
# Gujarat_Anand appended
# Gujarat_Bhavnagar appended
# Gujarat_Junagadh appended
# Gujarat_Jamnagar appended
# Gujarat_Devbhoomi Dwarka appended
# Gujarat_Morbi appended
# Gujarat_Navsari appended
# Daman and Diu_Daman appended
# Daman and Diu_Diu appended
# Dadra and Nagar Haveli_Dadra and Nagar Haveli appended
# Maharashtra_Gondia appended
# Maharashtra_Bhandara appended
# Maharashtra_Jalgaon appended
# Maharashtra_Wardha appended
# Maharashtra_Buldhana appended
# Maharashtra_Akola appended
# Maharashtra_Nashik appended
# Maharashtra_Gadchiroli appended
# Maharashtra_Washim appended
# Maharashtra_Chandrapur appended
# Maharashtra_Yavatmal appended
# Maharashtra_Jalna appended
# Maharashtra_Ahmednagar appended
# Maharashtra_Hingoli appended
# Maharashtra_Nanded appended
# Maharashtra_Parbhani appended
# Maharashtra_Pune appended
# Maharashtra_Beed appended
# Maharashtra_Mumbai appended
# Maharashtra_Latur appended
# Maharashtra_Osmanabad appended
# Maharashtra_Solapur appended
# Maharashtra_Satara appended
# Maharashtra_Ratnagiri appended
# Maharashtra_Sangli appended
# Maharashtra_Kolhapur appended
# Maharashtra_Sindhudurg appended
# Maharashtra_Thane appended
# Maharashtra_Palghar appended
# Maharashtra_Nandurbar appended
# Maharashtra_Amravati appended
# Maharashtra_Dhule appended
# Maharashtra_Nagpur appended
# Maharashtra_Aurangabad appended
# Maharashtra_Raigarh appended
# Maharashtra_Mumbai Suburban appended
# Andhra Pradesh_Srikakulam appended
# Andhra Pradesh_Vizianagaram appended
# Andhra Pradesh_Vishakhapatnam appended
# Andhra Pradesh_Krishna appended
# Andhra Pradesh_Guntur appended
# Andhra Pradesh_East Godavari appended
# Andhra Pradesh_Prakasam appended
# Andhra Pradesh_Kurnool appended
# Andhra Pradesh_Anantapuram appended
# Andhra Pradesh_Sri Potti Sriramulu Nellore District appended
# Andhra Pradesh_West Godavari appended
# Andhra Pradesh_YSR District appended
# Andhra Pradesh_Chittoor appended
# Karnataka_Bidar appended
# Karnataka_Gulbarga appended
# Karnataka_Belagavi appended
# Karnataka_Yadgir appended
# Karnataka_Bagalkot appended
# Karnataka_Raichur appended
# Karnataka_Koppal appended
# Karnataka_Gadag appended
# Karnataka_Bellary appended
# Karnataka_Dharwad appended
# Karnataka_Uttara Kannada appended
# Karnataka_Haveri appended
# Karnataka_Chitradurga appended
# Karnataka_Davanagere appended
# Karnataka_Shimoga appended
# Karnataka_Udupi appended
# Karnataka_Chikkamagaluru appended
# Karnataka_Chikballapur appended
# Karnataka_Hassan appended
# Karnataka_Kolar appended
# Karnataka_Bangalore Rural appended
# Karnataka_Dakshina Kannada appended
# Karnataka_Bangalore Urban appended
# Karnataka_Kodagu appended
# Karnataka_Chamarajanagar appended
# Karnataka_Tumkur appended
# Karnataka_Ramanagara appended
# Karnataka_Mandya appended
# Karnataka_Mysuru appended
# Karnataka_Bijapur appended
# Goa_North Goa appended
# Goa_South Goa appended
# Lakshadweep_Lakshadweep appended
# Kerala_Kasaragod appended
# Kerala_Wayanad appended
# Kerala_Kozhikode appended
# Kerala_Malappuram appended
# Kerala_Palakkad appended
# Kerala_Thrissur appended
# Kerala_Idukki appended
# Kerala_Ernakulam appended
# Kerala_Alappuzha appended
# Kerala_Kottayam appended
# Kerala_Pathanamthitta appended
# Kerala_Kollam appended
# Kerala_Thiruvananthapuram appended
# Kerala_Kannur appended
# Tamil Nadu_Krishnagiri appended
# Tamil Nadu_Tiruvannamalai appended
# Tamil Nadu_Dharmapuri appended
# Tamil Nadu_Salem appended
# Tamil Nadu_Erode appended
# Tamil Nadu_Nilgiris appended
# Tamil Nadu_Namakkal appended
# Tamil Nadu_Perambalur appended
# Tamil Nadu_Coimbatore appended
# Tamil Nadu_Tiruchirappalli appended
# Tamil Nadu_Ariyalur appended
# Tamil Nadu_Tiruppur appended
# Tamil Nadu_Thanjavur appended
# Tamil Nadu_Karur appended
# Tamil Nadu_Thiruvarur appended
# Tamil Nadu_Dindigul appended
# Tamil Nadu_Madurai appended
# Tamil Nadu_Theni appended
# Tamil Nadu_Virudhunagar appended
# Tamil Nadu_Thoothukudi appended
# Tamil Nadu_Kanyakumari appended
# Tamil Nadu_Villupuram appended
# Tamil Nadu_Cuddalore appended
# Tamil Nadu_Pudukkottai appended
# Tamil Nadu_Sivaganga appended
# Tamil Nadu_Ramanathapuram appended
# Tamil Nadu_Nagapattinam appended
# Tamil Nadu_Kallakurichi appended
# Tamil Nadu_Tenkasi appended
# Tamil Nadu_Tirunelveli appended
# Tamil Nadu_Vellore appended
# Tamil Nadu_Ranipet appended
# Tamil Nadu_Tirupathur appended
# Tamil Nadu_Kanchipuram appended
# Tamil Nadu_Chengalpattu appended
# Tamil Nadu_Chennai appended
# Tamil Nadu_Tiruvallur appended
# Puducherry_Pondicherry appended
# Puducherry_Karaikal appended
# Puducherry_Mahe appended
# Puducherry_Yanam appended
# Andaman and Nicobar Islands_North and Middle Andaman appended
# Andaman and Nicobar Islands_South Andaman appended
# Andaman and Nicobar Islands_Nicobars appended
# Telangana_Adilabad appended
# Telangana_Hyderabad appended
# Telangana_Jagitial appended
# Telangana_Jangoan appended
# Telangana_Mulugu appended
# Telangana_Jogulamba Gadwal appended
# Telangana_Kamareddy appended
# Telangana_Karimnagar appended
# Telangana_Khammam appended
# Telangana_Kumuram Bheem Asifabad appended
# Telangana_Mahabubabad appended
# Telangana_Mahabubnagar appended
# Telangana_Mancherial appended
# Telangana_Medak appended
# Telangana_Medchal Malkajgiri appended
# Telangana_Nagarkurnool appended
# Telangana_Nalgonda appended
# Telangana_Nirmal appended
# Telangana_Nizamabad appended
# Telangana_Peddapalli appended
# Telangana_Rajanna Sircilla appended
# Telangana_Ranga Reddy appended
# Telangana_Sangareddy appended
# Telangana_Siddipet appended
# Telangana_Suryapet appended
# Telangana_Vikarabad appended
# Telangana_Wanaparthy appended
# Telangana_Warangal Rural appended
# Telangana_Warangal appended
# Telangana_Yadadri Bhuvanagiri appended
# Telangana_Bhadradri Kothagudem appended
# Telangana_Jayashankar appended
# Telangana_Narayanpet appended
# Ladakh_Leh appended
# Ladakh_Kargil appended

# %%
final_concat = pd.concat(data_dic.values(), ignore_index=True)

# %%
final_concat.drop(columns=['latitude', 'longitude'], inplace=True)

# %%
import seaborn as sns

# %%
len(final_concat['adm1'].unique())
# Out:
# 37

# %%
final_concat.to_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/THI/india/daily_max_THI.csv')
