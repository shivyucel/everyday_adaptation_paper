# %%
import pandas as pd
### use xarray for extracting temperature data from .nc files
import xarray as xr 
import numpy as np
import geopandas as gpd
import datetime
import os
import metpy.calc as mpcalc
from metpy.units import units
import rioxarray
import zipfile
import os
# Directory to extract files
extract_dir = '/Users/liangyuan/Desktop/ERA5_heatwave/extracted'

#Geometry of China
gdf = gpd.read_file('china_city.geojson')

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Step 1: Get daily maximum THI values at each pixel cell

# %%
#Concatenate data from all 5 years along the time axis
#Change the time zone
#Convert temperature and dewpoint to Celcius
#Calculate relative humidity using metpy package
#Calculate heat index using metpy

# Resample to get the DAILY MAXIMUM heat index value at each pixel cell -- 'concat_daily_max'

# %%
data_arrays = []

for year in ['2019', '2020', '2021', '2022','2023']:

    #May to September files
    nc_file = os.path.join(extract_dir, f'era5_land_dewpoint_China_{year}.nc')
    ds_main = xr.open_dataset(nc_file,engine='h5netcdf')

    #Extra April day
    nc_file_04 = os.path.join(extract_dir, f'era5_land_dewpoint_China_{year}_04.nc')
    ds_04 = xr.open_dataset(nc_file_04,engine='h5netcdf')

    #extra October day
    nc_file_10 = os.path.join(extract_dir, f'era5_land_dewpoint_China_{year}_10.nc')
    ds_10 = xr.open_dataset(nc_file_10,engine='h5netcdf')

    #concatenate
    ds = xr.concat([ds_main, ds_04, ds_10], dim='valid_time')
    ds = ds.sortby('valid_time')

    # Rename 'valid_time' to 'time'
    ds = ds.rename({'valid_time': 'time'})
    
    # Convert time to the desired timezone (e.g., 'China/Beijing')
    ds['time'] = ds['time'] + pd.Timedelta(hours=8)

    # Convert from Kelvin to Celsius
    ds['t2m'] = ds['t2m'] - 273.15
    ds['d2m'] = ds['d2m'] - 273.15

    # Calculate relative humidity
    ds['rh'] = mpcalc.relative_humidity_from_dewpoint(ds['t2m'] * units.degC, ds['d2m'] * units.degC)
    ds['rh'] = ds['rh'] * 100

    # Calculate THI using metpy's heat_index function
    ds['thi'] = mpcalc.heat_index(ds['t2m'] * units.degC, ds['rh'] * units.percent, mask_undefined=False)


    daily_max_thi = ds.resample(time='1D').max()

    data_arrays.append(daily_max_thi)

    print('appended')

    
concat_daily_max = xr.concat(data_arrays, dim='time')
concat_daily_max.to_netcdf('concat_array.nc')
# Out:
# appended
# appended
# appended
# appended
# appended

# %%
#Add coordinate projection to raster file

# %%
concat_daily_max = xr.open_dataset('concat_array.nc',engine='h5netcdf')
concat_daily_max.rio.write_crs(4326, inplace=True)
# Out:
# <xarray.Dataset>
# Dimensions:      (latitude: 379, longitude: 635, time: 785)
# Coordinates:
#     number       int64 ...
#   * latitude     (latitude) float64 54.4 54.3 54.2 54.1 ... 16.9 16.8 16.7 16.6
#   * longitude    (longitude) float64 72.8 72.9 73.0 73.1 ... 136.0 136.1 136.2
#   * time         (time) datetime64[ns] 2019-04-30 2019-05-01 ... 2023-10-03
#     spatial_ref  int64 0
# Data variables:
#     t2m          (time, latitude, longitude) float32 ...
#     d2m          (time, latitude, longitude) float32 ...
#     rh           (time, latitude, longitude) float32 ...
#     thi          (time, latitude, longitude) float64 ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-15T08:43 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
# For each location in GeoDataFrame of country
# Clip all pixel cells with intersect with shape of the location
# Get the mean value at each time period (the daily maximums calculated in step 1)
# Output is the mean of the daily maximums on each day for each county
# saved into a dictionary

# %% [markdown]
# ### Step 2: Clip all pixels with intersect with each location, get the mean of those daily maximum values

# %%
data_dic = {}

for idx, row in gdf.iterrows():

    adm2 = row['adm2']
    adm1 = row['adm1']
    # Clip the THI DataArray using the geometry
    try:
        clipped_thi = concat_daily_max.rio.clip([row.geometry], all_touched=True, crs=gdf.crs)
        
        # Convert the clipped THI DataArray to a DataFrame
        clipped_thi_df = clipped_thi.to_dataframe().reset_index()
        
        # Add the adm2 information to the DataFrame

        clipped_thi_df = clipped_thi_df.groupby('time').mean(numeric_only=True).reset_index()

        clipped_thi_df['adm2'] = adm2
        
        clipped_thi_df['adm1'] = adm1

        data_dic[f'{adm1}_{adm2}'] = clipped_thi_df

        print(f'{adm1}_{adm2} appended')

    except:
        continue
# Out:
# beijingshi_beijingshi appended
# tianjinshi_tianjinshi appended
# hebeisheng_shijiazhuangshi appended
# hebeisheng_tangshanshi appended
# hebeisheng_qinhuangdaoshi appended
# hebeisheng_handanshi appended
# hebeisheng_xingtaishi appended
# hebeisheng_baodingshi appended
# hebeisheng_zhangjiakoushi appended
# hebeisheng_chengdeshi appended
# hebeisheng_cangzhoushi appended
# hebeisheng_langfangshi appended
# hebeisheng_hengshuishi appended
# shanxisheng_taiyuanshi appended
# shanxisheng_datongshi appended
# shanxisheng_yangquanshi appended
# shanxisheng_zhangzhishi appended
# shanxisheng_jinchengshi appended
# shanxisheng_shuozhoushi appended
# shanxisheng_jinzhongshi appended
# shanxisheng_yunchengshi appended
# shanxisheng_xinzhoushi appended
# shanxisheng_linfenshi appended
# shanxisheng_lvliangshi appended
# neimengguzizhiqu_huhehaoteshi appended
# neimengguzizhiqu_baotoushi appended
# neimengguzizhiqu_wuhaishi appended
# neimengguzizhiqu_chifengshi appended
# neimengguzizhiqu_tongliaoshi appended
# neimengguzizhiqu_eerduosishi appended
# neimengguzizhiqu_hulunbeiershi appended
# neimengguzizhiqu_bayannaoershi appended
# neimengguzizhiqu_wulanchabushi appended
# neimengguzizhiqu_xinganmeng appended
# neimengguzizhiqu_xilinguoleimeng appended
# neimengguzizhiqu_alashanmeng appended
# liaoningsheng_shenyangshi appended
# liaoningsheng_dalianshi appended
# liaoningsheng_anshanshi appended
# liaoningsheng_fushunshi appended
# liaoningsheng_benxishi appended
# liaoningsheng_dandongshi appended
# liaoningsheng_jinzhoushi appended
# liaoningsheng_yingkoushi appended
# liaoningsheng_fuxinshi appended
# liaoningsheng_liaoyangshi appended
# liaoningsheng_panjinshi appended
# liaoningsheng_tielingshi appended
# liaoningsheng_zhaoyangshi appended
# liaoningsheng_huludaoshi appended
# jilinsheng_changchunshi appended
# jilinsheng_jilinshi appended
# jilinsheng_sipingshi appended
# jilinsheng_liaoyuanshi appended
# jilinsheng_tonghuashi appended
# jilinsheng_baishanshi appended
# jilinsheng_songyuanshi appended
# jilinsheng_baichengshi appended
# jilinsheng_yanbianchaoxianzuzizhizhou appended
# heilongjiangsheng_haerbinshi appended
# heilongjiangsheng_qiqihaershi appended
# heilongjiangsheng_jixishi appended
# heilongjiangsheng_hegangshi appended
# heilongjiangsheng_shuangyashanshi appended
# heilongjiangsheng_daqingshi appended
# heilongjiangsheng_yichunshi_hlj appended
# heilongjiangsheng_jiamusishi appended
# heilongjiangsheng_qitaiheshi appended
# heilongjiangsheng_mudanjiangshi appended
# heilongjiangsheng_heiheshi appended
# heilongjiangsheng_suihuashi appended
# heilongjiangsheng_daxinganlingdiqu appended
# shanghaishi_shanghaishi appended
# jiangsusheng_nanjingshi appended
# jiangsusheng_wuxishi appended
# jiangsusheng_xuzhoushi appended
# jiangsusheng_changzhoushi appended
# jiangsusheng_suzhoushi_js appended
# jiangsusheng_nantongshi appended
# jiangsusheng_lianyungangshi appended
# jiangsusheng_huaianshi appended
# jiangsusheng_yanchengshi appended
# jiangsusheng_yangzhoushi appended
# jiangsusheng_zhenjiangshi appended
# jiangsusheng_taizhoushi_js appended
# jiangsusheng_suqianshi appended
# zhejiangsheng_hangzhoushi appended
# zhejiangsheng_ningboshi appended
# zhejiangsheng_wenzhoushi appended
# zhejiangsheng_jiaxingshi appended
# zhejiangsheng_huzhoushi appended
# zhejiangsheng_shaoxingshi appended
# zhejiangsheng_jinhuashi appended
# zhejiangsheng_quzhoushi appended
# zhejiangsheng_zhoushanshi appended
# zhejiangsheng_taizhoushi appended
# zhejiangsheng_lishuishi appended
# anhuisheng_hefeishi appended
# anhuisheng_wuhushi appended
# anhuisheng_bengbushi appended
# anhuisheng_huainanshi appended
# anhuisheng_maanshanshi appended
# anhuisheng_huaibeishi appended
# anhuisheng_tonglingshi appended
# anhuisheng_anqingshi appended
# anhuisheng_huangshanshi appended
# anhuisheng_chuzhoushi appended
# anhuisheng_fuyangshi appended
# anhuisheng_suzhoushi appended
# anhuisheng_luanshi appended
# anhuisheng_bozhoushi appended
# anhuisheng_chizhoushi appended
# anhuisheng_xuanchengshi appended
# fujiansheng_fuzhoushi_fj appended
# fujiansheng_xiamenshi appended
# fujiansheng_putianshi appended
# fujiansheng_sanmingshi appended
# fujiansheng_quanzhoushi appended
# fujiansheng_zhangzhoushi appended
# fujiansheng_nanpingshi appended
# fujiansheng_longyanshi appended
# fujiansheng_ningdeshi appended
# jiangxisheng_nanchangshi appended
# jiangxisheng_jingdezhenshi appended
# jiangxisheng_pingxiangshi appended
# jiangxisheng_jiujiangshi appended
# jiangxisheng_xinyushi appended
# jiangxisheng_yingtanshi appended
# jiangxisheng_ganzhoushi appended
# jiangxisheng_jianshi appended
# jiangxisheng_yichunshi appended
# jiangxisheng_fuzhoushi appended
# jiangxisheng_shangraoshi appended
# shandongsheng_jinanshi appended
# shandongsheng_qingdaoshi appended
# shandongsheng_ziboshi appended
# shandongsheng_zaozhuangshi appended
# shandongsheng_dongyingshi appended
# shandongsheng_yantaishi appended
# shandongsheng_weifangshi appended
# shandongsheng_jiningshi appended
# shandongsheng_taianshi appended
# shandongsheng_weihaishi appended
# shandongsheng_rizhaoshi appended
# shandongsheng_linyishi appended
# shandongsheng_dezhoushi appended
# shandongsheng_liaochengshi appended
# shandongsheng_binzhoushi appended
# shandongsheng_hezeshi appended
# henansheng_zhengzhoushi appended
# henansheng_kaifengshi appended
# henansheng_luoyangshi appended
# henansheng_pingdingshanshi appended
# henansheng_anyangshi appended
# henansheng_hebishi appended
# henansheng_xinxiangshi appended
# henansheng_jiaozuoshi appended
# henansheng_puyangshi appended
# henansheng_xuchangshi appended
# henansheng_taheshi appended
# henansheng_sanmenxiashi appended
# henansheng_nanyangshi appended
# henansheng_shangqiushi appended
# henansheng_xinyangshi appended
# henansheng_zhoukoushi appended
# henansheng_zhumadianshi appended
# henansheng_jiyuanshi appended
# hubeisheng_wuhanshi appended
# hubeisheng_huangshishi appended
# hubeisheng_shiyanshi appended
# hubeisheng_yichangshi appended
# hubeisheng_xiangyangshi appended
# hubeisheng_ezhoushi appended
# hubeisheng_jingmenshi appended
# hubeisheng_xiaoganshi appended
# hubeisheng_jingzhoushi appended
# hubeisheng_huanggangshi appended
# hubeisheng_xianningshi appended
# hubeisheng_suizhoushi appended
# hubeisheng_enshitujiazumiaozuzizhizhou appended
# hubeisheng_xiantaoshi appended
# hubeisheng_qianjiangshi appended
# hubeisheng_tianmenshi appended
# hubeisheng_shennongjialinqu appended
# hunansheng_changshashi appended
# hunansheng_zhuzhoushi appended
# hunansheng_xiangtanshi appended
# hunansheng_hengyangshi appended
# hunansheng_shaoyangshi appended
# hunansheng_yueyangshi appended
# hunansheng_changdeshi appended
# hunansheng_zhangjiajieshi appended
# hunansheng_yiyangshi appended
# hunansheng_chenzhoushi appended
# hunansheng_yongzhoushi appended
# hunansheng_huaihuashi appended
# hunansheng_loudishi appended
# hunansheng_xiangxitujiazumiaozuzizhizhou appended
# guangdongsheng_guangzhoushi appended
# guangdongsheng_shaoguanshi appended
# guangdongsheng_shenzhenshi appended
# guangdongsheng_zhuhaishi appended
# guangdongsheng_shantoushi appended
# guangdongsheng_foshanshi appended
# guangdongsheng_jiangmenshi appended
# guangdongsheng_zhanjiangshi appended
# guangdongsheng_maomingshi appended
# guangdongsheng_zhaoqingshi appended
# guangdongsheng_huizhoushi appended
# guangdongsheng_meizhoushi appended
# guangdongsheng_shanweishi appended
# guangdongsheng_heyuanshi appended
# guangdongsheng_yangjiangshi appended
# guangdongsheng_qingyuanshi appended
# guangdongsheng_dongguanshi appended
# guangdongsheng_zhongshanshi appended
# guangdongsheng_chaozhoushi appended
# guangdongsheng_jieyangshi appended
# guangdongsheng_yunfushi appended
# guangxizhuangzuzizhiqu_nanningshi appended
# guangxizhuangzuzizhiqu_liuzhoushi appended
# guangxizhuangzuzizhiqu_guilinshi appended
# guangxizhuangzuzizhiqu_wuzhoushi appended
# guangxizhuangzuzizhiqu_beihaishi appended
# guangxizhuangzuzizhiqu_fangchenggangshi appended
# guangxizhuangzuzizhiqu_qinzhoushi appended
# guangxizhuangzuzizhiqu_guigangshi appended
# guangxizhuangzuzizhiqu_yulinshi appended
# guangxizhuangzuzizhiqu_baiseshi appended
# guangxizhuangzuzizhiqu_hezhoushi appended
# guangxizhuangzuzizhiqu_hechishi appended
# guangxizhuangzuzizhiqu_laibinshi appended
# guangxizhuangzuzizhiqu_chongzuoshi appended
# hainansheng_haikoushi appended
# hainansheng_sanyashi appended
# hainansheng_sanshashi appended
# hainansheng_danzhoushi appended
# hainansheng_wuzhishanshi appended
# hainansheng_qionghaishi appended
# hainansheng_wenchangshi appended
# hainansheng_wanningshi appended
# hainansheng_dongfangshi appended
# hainansheng_dinganxian appended
# hainansheng_tunchangxian appended
# hainansheng_chengmaixian appended
# hainansheng_lingaoxian appended
# hainansheng_baishalizuzizhixian appended
# hainansheng_changjianglizuzizhixian appended
# hainansheng_ledonglizuzizhixian appended
# hainansheng_lingshuilizuzizhixian appended
# hainansheng_baotinglizumiaozuzizhixian appended
# hainansheng_qiongzhonglizumiaozuzizhixian appended
# chongqingshi_chongqingshi appended
# sichuansheng_chengdushi appended
# sichuansheng_zigongshi appended
# sichuansheng_panzhihuashi appended
# sichuansheng_luzhoushi appended
# sichuansheng_deyangshi appended
# sichuansheng_mianyangshi appended
# sichuansheng_guangyuanshi appended
# sichuansheng_suiningshi appended
# sichuansheng_neijiangshi appended
# sichuansheng_leshanshi appended
# sichuansheng_nanchongshi appended
# sichuansheng_meishanshi appended
# sichuansheng_yibinshi appended
# sichuansheng_guanganshi appended
# sichuansheng_dazhoushi appended
# sichuansheng_yaanshi appended
# sichuansheng_bazhongshi appended
# sichuansheng_ziyangshi appended
# sichuansheng_abazangzuqiangzuzizhizhou appended
# sichuansheng_ganzizangzuzizhizhou appended
# sichuansheng_liangshanyizuzizhizhou appended
# guizhousheng_guiyangshi appended
# guizhousheng_liupanshuishi appended
# guizhousheng_zunyishi appended
# guizhousheng_anshunshi appended
# guizhousheng_bijieshi appended
# guizhousheng_tongrenshi appended
# guizhousheng_qianxinanbuyizumiaozuzizhizhou appended
# guizhousheng_qiandongnanmiaozudongzuzizhizhou appended
# guizhousheng_qiannanbuyizumiaozuzizhizhou appended
# yunnansheng_kunmingshi appended
# yunnansheng_qujingshi appended
# yunnansheng_yuxishi appended
# yunnansheng_baoshanshi appended
# yunnansheng_zhaotongshi appended
# yunnansheng_lijiangshi appended
# yunnansheng_puershi appended
# yunnansheng_lincangshi appended
# yunnansheng_chuxiongyizuzizhizhou appended
# yunnansheng_honghehanizuyizuzizhizhou appended
# yunnansheng_wenshanzhuangzumiaozuzizhizhou appended
# yunnansheng_xishuangbannadaizuzizhizhou appended
# yunnansheng_dalibaizuzizhizhou appended
# yunnansheng_dehongdaizujingpozuzizhizhou appended
# yunnansheng_nujianglisuzuzizhizhou appended
# yunnansheng_diqingzangzuzizhizhou appended
# xizangzizhiqu_lasashi appended
# xizangzizhiqu_rikazeshi appended
# xizangzizhiqu_changdushi appended
# xizangzizhiqu_linzhishi appended
# xizangzizhiqu_shannanshi appended
# xizangzizhiqu_naqushi appended
# xizangzizhiqu_alidiqu appended
# shaanxisheng_xianshi appended
# shaanxisheng_tongchuanshi appended
# shaanxisheng_baojishi appended
# shaanxisheng_xianyangshi appended
# shaanxisheng_weinanshi appended
# shaanxisheng_yananshi appended
# shaanxisheng_hanzhongshi appended
# shaanxisheng_yulinshi_sx appended
# shaanxisheng_ankangshi appended
# shaanxisheng_shangluoshi appended
# gansusheng_lanzhoushi appended
# gansusheng_jiayuguanshi appended
# gansusheng_jinchangshi appended
# gansusheng_baiyinshi appended
# gansusheng_tianshuishi appended
# gansusheng_wuweishi appended
# gansusheng_zhangyeshi appended
# gansusheng_pingliangshi appended
# gansusheng_jiuquanshi appended
# gansusheng_qingyangshi appended
# gansusheng_dingxishi appended
# gansusheng_longnanshi appended
# gansusheng_linxiahuizuzizhizhou appended
# gansusheng_gannanzangzuzizhizhou appended
# gansusheng_zhongnongfashandanmachang appended
# gansusheng_lianhuashanfengjinglinziranbaohuqu appended
# gansusheng_taizishantianranlinbaohuqu appended
# qinghaisheng_xiningshi appended
# qinghaisheng_haidongshi appended
# qinghaisheng_haibeizangzuzizhizhou appended
# qinghaisheng_huangnanzangzuzizhizhou appended
# qinghaisheng_hainanzangzuzizhizhou appended
# qinghaisheng_guoluozangzuzizhizhou appended
# qinghaisheng_yushuzangzuzizhizhou appended
# qinghaisheng_haiximengguzuzangzuzizhizhou appended
# ningxiahuizuzizhiqu_yinchuanshi appended
# ningxiahuizuzizhiqu_shizuishanshi appended
# ningxiahuizuzizhiqu_wuzhongshi appended
# ningxiahuizuzizhiqu_guyuanshi appended
# ningxiahuizuzizhiqu_zhongweishi appended
# xinjiangweiwuerzizhiqu_wulumuqishi appended
# xinjiangweiwuerzizhiqu_kelamayishi appended
# xinjiangweiwuerzizhiqu_tulufanshi appended
# xinjiangweiwuerzizhiqu_hamishi appended
# xinjiangweiwuerzizhiqu_changjihuizuzizhizhou appended
# xinjiangweiwuerzizhiqu_boertalamengguzizhizhou appended
# xinjiangweiwuerzizhiqu_bayinguolengmengguzizhizhou appended
# xinjiangweiwuerzizhiqu_akesudiqu appended
# xinjiangweiwuerzizhiqu_kezileisukeerkezizizhizhou appended
# xinjiangweiwuerzizhiqu_kashidiqu appended
# xinjiangweiwuerzizhiqu_hetiandiqu appended
# xinjiangweiwuerzizhiqu_yilihasakezizhizhou appended
# xinjiangweiwuerzizhiqu_tachengdiqu appended
# xinjiangweiwuerzizhiqu_aleitaidiqu appended
# xinjiangweiwuerzizhiqu_shihezishi appended
# xinjiangweiwuerzizhiqu_alaershi appended
# xinjiangweiwuerzizhiqu_tumushukeshi appended
# xinjiangweiwuerzizhiqu_wujiaqushi appended
# xinjiangweiwuerzizhiqu_beitunshi appended
# xinjiangweiwuerzizhiqu_tiemenguanshi appended
# xinjiangweiwuerzizhiqu_shuangheshi appended
# xinjiangweiwuerzizhiqu_kekedalashi appended
# xinjiangweiwuerzizhiqu_kunyushi appended
# xinjiangweiwuerzizhiqu_huyangheshi appended
# xinjiangweiwuerzizhiqu_xinxingshi appended
# xinjiangweiwuerzizhiqu_baiyangshi appended
# taiwansheng_taiwansheng appended
# xianggangtebiexingzhengqu_xianggangtebiexingzhengqu appended
# aomentebiexingzhengqu_aomentebiexingzhengqu appended

# %%
#Convert dictionary to dataframe

# %%
final_concat = pd.concat(data_dic.values(), ignore_index=True)

# %%
final_concat.drop(columns=['latitude', 'longitude'], inplace=True)

# %%
final_concat.groupby('adm2')['thi'].mean().sort_values()
# Out:
# adm2
# alidiqu                  7.385272
# yushuzangzuzizhizhou     7.634543
# naqushi                  7.936676
# rikazeshi                8.366720
# lasashi                  9.156159
#                           ...
# wenchangshi             38.389867
# lingaoxian              38.476631
# dinganxian              38.561873
# haikoushi               38.712540
# sanshashi                     NaN
# Name: thi, Length: 375, dtype: float64

# %%
#Save as file

# %%
final_concat.to_csv('daily_max_THI.csv')
